# %%
import ezdxf

def inspect_dxf(file_path):
    try:
        # DXF 파일 열기
        doc = ezdxf.readfile(file_path)
        print(f"DXF 파일 '{file_path}' 열기 성공")
        
        # 기본 정보
        print("\n=== 기본 정보 ===")
        print(f"DXF 버전: {doc.dxfversion}")
        print(f"도면 단위: {doc.units}")

        # 레이어 정보
        print("\n=== 레이어 목록 ===")
        for layer in doc.layers:
            print(f"레이어 이름: {layer.dxf.name}, 색상: {layer.dxf.color}, 선형: {layer.dxf.linetype}")

        # 모델 스페이스의 엔티티 정보
        print("\n=== 모델 스페이스 엔티티 ===")
        msp = doc.modelspace()
        entity_count = {}
        
        for entity in msp:
            entity_type = entity.dxftype()
            entity_count[entity_type] = entity_count.get(entity_type, 0) + 1
        
        for entity_type, count in entity_count.items():
            print(f"엔티티 타입: {entity_type}, 개수: {count}")

        # 블록 정보
        print("\n=== 블록 목록 ===")
        for block in doc.blocks:
            print(f"블록 이름: {block.name}")

    except Exception as e:
        print(f"오류 발생: {e}")

# 사용 예시
file_path = 'C:/Users/user/Desktop/인천시공공데이터공모전/376064.dxf'  # DXF 파일 경로로 변경
inspect_dxf(file_path)
# Out:
# DXF 파일 'C:/Users/user/Desktop/인천시공공데이터공모전/376064.dxf' 열기 성공
#
# === 기본 정보 ===
# DXF 버전: AC1015
# 도면 단위: 0
#
# === 레이어 목록 ===
# 레이어 이름: 0, 색상: 7, 선형: Continuous
# 레이어 이름: H0049233, 색상: 7, 선형: Continuous
# 레이어 이름: G0038232, 색상: 3, 선형: Continuous
# 레이어 이름: H0027133, 색상: 7, 선형: Continuous
# 레이어 이름: H0027311, 색상: 1, 선형: Continuous
# 레이어 이름: B0014115, 색상: 7, 선형: Continuous
# 레이어 이름: B0014116, 색상: 7, 선형: Continuous
# 레이어 이름: B0014117, 색상: 7, 선형: Continuous
# 레이어 이름: B0014118, 색상: 7, 선형: Continuous
# 레이어 이름: B0014113, 색상: 7, 선형: Continuous
# 레이어 이름: B0014112, 색상: 7, 선형: Continuous
# 레이어 이름: B0014111, 색상: 7, 선형: Continuous
# 레이어 이름: A0160024, 색상: 7, 선형: Continuous
# 레이어 이름: A0151116, 색상: 7, 선형: Continuous
# 레이어 이름: H0049114, 색상: 7, 선형: Continuous
# 레이어 이름: A0073340, 색상: 7, 선형: Continuous
# 레이어 이름: A0063321, 색상: 7, 선형: Continuous
# 레이어 이름: A0053326, 색상: 32, 선형: Continuous
# 레이어 이름: A0043325, 색상: 32, 선형: Continuous
# 레이어 이름: A0033327, 색상: 32, 선형: Continuous
# 레이어 이름: E0042326, 색상: 5, 선형: Continuous
# 레이어 이름: E0032111, 색상: 5, 선형: Continuous
# 레이어 이름: E0022115, 색상: 7, 선형: Continuous
# 레이어 이름: E0022112, 색상: 5, 선형: Continuous
# 레이어 이름: D0015213, 색상: 3, 선형: Continuous
# 레이어 이름: D0015212, 색상: 3, 선형: Continuous
# 레이어 이름: D0015211, 색상: 5, 선형: Continuous
# 레이어 이름: D0025111, 색상: 3, 선형: Continuous
# 레이어 이름: C0523121, 색상: 1, 선형: Continuous
# 레이어 이름: C0393323, 색상: 7, 선형: Continuous
# 레이어 이름: C0390130, 색상: 7, 선형: Continuous
# 레이어 이름: H0049160, 색상: 7, 선형: Continuous
# 레이어 이름: C0305316, 색상: 1, 선형: Continuous
# 레이어 이름: C0295113, 색상: 7, 선형: Continuous
# 레이어 이름: C0152261, 색상: 5, 선형: Continuous
# 레이어 이름: C0096311, 색상: 5, 선형: Continuous
# 레이어 이름: H0027135, 색상: 7, 선형: Continuous
# 레이어 이름: H0027312, 색상: 5, 선형: Continuous
# 레이어 이름: H0027134, 색상: 7, 선형: Continuous
# 레이어 이름: G0038231, 색상: 3, 선형: Continuous
# 레이어 이름: G0037214, 색상: 32, 선형: Continuous
# 레이어 이름: G0037213, 색상: 32, 선형: Continuous
# 레이어 이름: G0022324, 색상: 5, 선형: Continuous
# 레이어 이름: G0022314, 색상: 5, 선형: Continuous
# 레이어 이름: G0022323, 색상: 5, 선형: Continuous
# 레이어 이름: G0022313, 색상: 5, 선형: Continuous
# 레이어 이름: F0047224, 색상: 7, 선형: Continuous
# 레이어 이름: F0037223, 색상: 7, 선형: Continuous
# 레이어 이름: F0037222, 색상: 7, 선형: Continuous
# 레이어 이름: F0037221, 색상: 7, 선형: Continuous
# 레이어 이름: H0049140, 색상: 7, 선형: Continuous
# 레이어 이름: G0022322, 색상: 30, 선형: Continuous
# 레이어 이름: G0022312, 색상: 5, 선형: Continuous
# 레이어 이름: G0022321, 색상: 7, 선형: Continuous
# 레이어 이름: G0022311, 색상: 5, 선형: Continuous
# 레이어 이름: H0049224, 색상: 7, 선형: Continuous
# 레이어 이름: H0049216, 색상: 7, 선형: Continuous
# 레이어 이름: G0018117, 색상: 7, 선형: Continuous
# 레이어 이름: H0049215, 색상: 7, 선형: Continuous
# 레이어 이름: H0049222, 색상: 7, 선형: Continuous
# 레이어 이름: G0018112, 색상: 7, 선형: Continuous
# 레이어 이름: F0047225, 색상: 7, 선형: Continuous
# 레이어 이름: F0017131, 색상: 7, 선형: Continuous
# 레이어 이름: F0017114, 색상: 7, 선형: Continuous
# 레이어 이름: F0017111, 색상: 30, 선형: Continuous
# 레이어 이름: E0082122, 색상: 5, 선형: Continuous
# 레이어 이름: E0082121, 색상: 5, 선형: Continuous
# 레이어 이름: H0049131, 색상: 7, 선형: Continuous
# 레이어 이름: E0052114, 색상: 5, 선형: Continuous
# 레이어 이름: H0017334, 색상: 7, 선형: Continuous
# 레이어 이름: A0013111, 색상: 1, 선형: Continuous
# 레이어 이름: A0013113, 색상: 1, 선형: Continuous
# 레이어 이름: A0013114, 색상: 1, 선형: Continuous
# 레이어 이름: A0013116, 색상: 1, 선형: Continuous
# 레이어 이름: A0013117, 색상: 1, 선형: Continuous
# 레이어 이름: A0013118, 색상: 1, 선형: Continuous
# 레이어 이름: A0023119, 색상: 1, 선형: Continuous
# 레이어 이름: A0023211, 색상: 7, 선형: Continuous
# 레이어 이름: A0023213, 색상: 7, 선형: Continuous
# 레이어 이름: A0023214, 색상: 7, 선형: Continuous
# 레이어 이름: A0023216, 색상: 7, 선형: Continuous
# 레이어 이름: A0023217, 색상: 7, 선형: Continuous
# 레이어 이름: A0033324, 색상: 1, 선형: Continuous
# 레이어 이름: B0014114, 색상: 7, 선형: Continuous
# 레이어 이름: B0014219, 색상: 7, 선형: Continuous
# 레이어 이름: B0014511, 색상: 7, 선형: Continuous
# 레이어 이름: B0014524, 색상: 7, 선형: Continuous
# 레이어 이름: B0024120, 색상: 3, 선형: Continuous
# 레이어 이름: B0024127, 색상: 7, 선형: Continuous
# 레이어 이름: C0032254, 색상: 7, 선형: Continuous
# 레이어 이름: C0052211, 색상: 1, 선형: Continuous
# 레이어 이름: C0052212, 색상: 1, 선형: Continuous
# 레이어 이름: C0052221, 색상: 1, 선형: Continuous
# 레이어 이름: C0052222, 색상: 1, 선형: Continuous
# 레이어 이름: C0052231, 색상: 1, 선형: Continuous
# 레이어 이름: C0052232, 색상: 1, 선형: Continuous
# 레이어 이름: C0062241, 색상: 5, 선형: Continuous
# 레이어 이름: C0062243, 색상: 1, 선형: Continuous
# 레이어 이름: C0076116, 색상: 7, 선형: Continuous
# 레이어 이름: C0076117, 색상: 7, 선형: Continuous
# 레이어 이름: F0027132, 색상: 7, 선형: Continuous
# 레이어 이름: F0027217, 색상: 7, 선형: Continuous
# 레이어 이름: H0027313, 색상: 7, 선형: Continuous
# 레이어 이름: H0049154, 색상: 7, 선형: Continuous
# 레이어 이름: H0049225, 색상: 7, 선형: Continuous
# 레이어 이름: H0059153, 색상: 7, 선형: Continuous
# 레이어 이름: H0049226, 색상: 7, 선형: Continuous
# 레이어 이름: Defpoints, 색상: 7, 선형: Continuous
#
# === 모델 스페이스 엔티티 ===
# 엔티티 타입: LWPOLYLINE, 개수: 24958
# 엔티티 타입: TEXT, 개수: 1137
# 엔티티 타입: INSERT, 개수: 3528
#
# === 블록 목록 ===
# 블록 이름: *Model_Space
# 블록 이름: *Paper_Space
# 블록 이름: g0022322
# 블록 이름: g0022321
# 블록 이름: f0027217
# 블록 이름: g0022324
# 블록 이름: g0022323
# 블록 이름: b0014219
# 블록 이름: B0014511
# 블록 이름: b0014524
# 블록 이름: c0096311
# 블록 이름: C0152261
# 블록 이름: c0305316
# 블록 이름: D0015211
# 블록 이름: d0015212
# 블록 이름: d0015213
# 블록 이름: e0042326
# 블록 이름: h0027311
# 블록 이름: h0027312
# 블록 이름: H0027313

# %%
import ezdxf

def print_all_dxf_details(file_path):
    try:
        # DXF 파일 열기
        doc = ezdxf.readfile(file_path)
        print(f"DXF 파일 '{file_path}' 열기 성공")

        # 1. 기본 정보
        print("\n=== 기본 정보 ===")
        print(f"DXF 버전: {doc.dxfversion}")
        print(f"도면 단위: {doc.units}")

        # 2. 레이어 정보
        print("\n=== 레이어 목록 (총 {len(list(doc.layers))}개) ===")
        for layer in doc.layers:
            print(f"레이어 이름: {layer.dxf.name}, 색상: {layer.dxf.color}, 선형: {layer.dxf.linetype}")

        # 3. 모델 스페이스 엔티티
        msp = doc.modelspace()
        print("\n=== 모델 스페이스 엔티티 ===")

        # LWPOLYLINE 추출
        print("\n--- LWPOLYLINE ---")
        lwpoly_count = 0
        print("샘플 (최대 5개):")
        for entity in msp.query("LWPOLYLINE"):
            lwpoly_count += 1
            if lwpoly_count <= 5:
                coords = [(point[0], point[1]) for point in entity.get_points()]
                print(f"Handle: {entity.dxf.handle}, 레이어: {entity.dxf.layer}, 닫힘: {entity.closed}")
                print(f"  좌표: {coords[:10]}{'...' if len(coords) > 10 else ''}")
        print(f"총 LWPOLYLINE 개수: {lwpoly_count}")

        # TEXT 추출
        print("\n--- TEXT ---")
        text_count = 0
        print("샘플 (최대 5개):")
        for entity in msp.query("TEXT"):
            text_count += 1
            if text_count <= 5:
                print(f"Handle: {entity.dxf.handle}, 레이어: {entity.dxf.layer}, 텍스트: {entity.dxf.text}")
                print(f"  삽입 위치: ({entity.dxf.insert[0]}, {entity.dxf.insert[1]}), 높이: {entity.dxf.height}, 회전: {entity.dxf.rotation}")
        print(f"총 TEXT 개수: {text_count}")

        # INSERT 추출
        print("\n--- INSERT ---")
        insert_count = 0
        print("샘플 (최대 5개):")
        for entity in msp.query("INSERT"):
            insert_count += 1
            if insert_count <= 5:
                print(f"Handle: {entity.dxf.handle}, 레이어: {entity.dxf.layer}, 블록 이름: {entity.dxf.name}")
                print(f"  삽입 위치: ({entity.dxf.insert[0]}, {entity.dxf.insert[1]}), 스케일: ({entity.dxf.xscale}, {entity.dxf.yscale}, {entity.dxf.zscale}), 회전: {entity.dxf.rotation}")
        print(f"총 INSERT 개수: {insert_count}")

        # 4. 블록 정보
        print("\n=== 블록 목록 (총 {len(list(doc.blocks))}개) ===")
        for block in doc.blocks:
            print(f"\n블록 이름: {block.name}")
            entities = list(block)
            print(f"  포함 엔티티 수: {len(entities)}")
            if len(entities) > 0:
                print("  샘플 엔티티 (최대 5개):")
                for i, entity in enumerate(entities[:5]):
                    print(f"  - 엔티티 {i+1}: 타입: {entity.dxftype()}, 레이어: {entity.dxf.layer}")
                    if entity.dxftype() == "LWPOLYLINE":
                        coords = [(p[0], p[1]) for p in entity.get_points()]
                        print(f"    좌표: {coords[:5]}{'...' if len(coords) > 5 else ''}")
                    elif entity.dxftype() == "TEXT":
                        print(f"    텍스트: {entity.dxf.text}")

    except Exception as e:
        print(f"오류 발생: {e}")

# 사용 예시
file_path = "C:/Users/user/Desktop/인천시공공데이터공모전/376064.dxf"
print_all_dxf_details(file_path)
# Out:
# DXF 파일 'C:/Users/user/Desktop/인천시공공데이터공모전/376064.dxf' 열기 성공
#
# === 기본 정보 ===
# DXF 버전: AC1015
# 도면 단위: 0
#
# === 레이어 목록 (총 {len(list(doc.layers))}개) ===
# 레이어 이름: 0, 색상: 7, 선형: Continuous
# 레이어 이름: H0049233, 색상: 7, 선형: Continuous
# 레이어 이름: G0038232, 색상: 3, 선형: Continuous
# 레이어 이름: H0027133, 색상: 7, 선형: Continuous
# 레이어 이름: H0027311, 색상: 1, 선형: Continuous
# 레이어 이름: B0014115, 색상: 7, 선형: Continuous
# 레이어 이름: B0014116, 색상: 7, 선형: Continuous
# 레이어 이름: B0014117, 색상: 7, 선형: Continuous
# 레이어 이름: B0014118, 색상: 7, 선형: Continuous
# 레이어 이름: B0014113, 색상: 7, 선형: Continuous
# 레이어 이름: B0014112, 색상: 7, 선형: Continuous
# 레이어 이름: B0014111, 색상: 7, 선형: Continuous
# 레이어 이름: A0160024, 색상: 7, 선형: Continuous
# 레이어 이름: A0151116, 색상: 7, 선형: Continuous
# 레이어 이름: H0049114, 색상: 7, 선형: Continuous
# 레이어 이름: A0073340, 색상: 7, 선형: Continuous
# 레이어 이름: A0063321, 색상: 7, 선형: Continuous
# 레이어 이름: A0053326, 색상: 32, 선형: Continuous
# 레이어 이름: A0043325, 색상: 32, 선형: Continuous
# 레이어 이름: A0033327, 색상: 32, 선형: Continuous
# 레이어 이름: E0042326, 색상: 5, 선형: Continuous
# 레이어 이름: E0032111, 색상: 5, 선형: Continuous
# 레이어 이름: E0022115, 색상: 7, 선형: Continuous
# 레이어 이름: E0022112, 색상: 5, 선형: Continuous
# 레이어 이름: D0015213, 색상: 3, 선형: Continuous
# 레이어 이름: D0015212, 색상: 3, 선형: Continuous
# 레이어 이름: D0015211, 색상: 5, 선형: Continuous
# 레이어 이름: D0025111, 색상: 3, 선형: Continuous
# 레이어 이름: C0523121, 색상: 1, 선형: Continuous
# 레이어 이름: C0393323, 색상: 7, 선형: Continuous
# 레이어 이름: C0390130, 색상: 7, 선형: Continuous
# 레이어 이름: H0049160, 색상: 7, 선형: Continuous
# 레이어 이름: C0305316, 색상: 1, 선형: Continuous
# 레이어 이름: C0295113, 색상: 7, 선형: Continuous
# 레이어 이름: C0152261, 색상: 5, 선형: Continuous
# 레이어 이름: C0096311, 색상: 5, 선형: Continuous
# 레이어 이름: H0027135, 색상: 7, 선형: Continuous
# 레이어 이름: H0027312, 색상: 5, 선형: Continuous
# 레이어 이름: H0027134, 색상: 7, 선형: Continuous
# 레이어 이름: G0038231, 색상: 3, 선형: Continuous
# 레이어 이름: G0037214, 색상: 32, 선형: Continuous
# 레이어 이름: G0037213, 색상: 32, 선형: Continuous
# 레이어 이름: G0022324, 색상: 5, 선형: Continuous
# 레이어 이름: G0022314, 색상: 5, 선형: Continuous
# 레이어 이름: G0022323, 색상: 5, 선형: Continuous
# 레이어 이름: G0022313, 색상: 5, 선형: Continuous
# 레이어 이름: F0047224, 색상: 7, 선형: Continuous
# 레이어 이름: F0037223, 색상: 7, 선형: Continuous
# 레이어 이름: F0037222, 색상: 7, 선형: Continuous
# 레이어 이름: F0037221, 색상: 7, 선형: Continuous
# 레이어 이름: H0049140, 색상: 7, 선형: Continuous
# 레이어 이름: G0022322, 색상: 30, 선형: Continuous
# 레이어 이름: G0022312, 색상: 5, 선형: Continuous
# 레이어 이름: G0022321, 색상: 7, 선형: Continuous
# 레이어 이름: G0022311, 색상: 5, 선형: Continuous
# 레이어 이름: H0049224, 색상: 7, 선형: Continuous
# 레이어 이름: H0049216, 색상: 7, 선형: Continuous
# 레이어 이름: G0018117, 색상: 7, 선형: Continuous
# 레이어 이름: H0049215, 색상: 7, 선형: Continuous
# 레이어 이름: H0049222, 색상: 7, 선형: Continuous
# 레이어 이름: G0018112, 색상: 7, 선형: Continuous
# 레이어 이름: F0047225, 색상: 7, 선형: Continuous
# 레이어 이름: F0017131, 색상: 7, 선형: Continuous
# 레이어 이름: F0017114, 색상: 7, 선형: Continuous
# 레이어 이름: F0017111, 색상: 30, 선형: Continuous
# 레이어 이름: E0082122, 색상: 5, 선형: Continuous
# 레이어 이름: E0082121, 색상: 5, 선형: Continuous
# 레이어 이름: H0049131, 색상: 7, 선형: Continuous
# 레이어 이름: E0052114, 색상: 5, 선형: Continuous
# 레이어 이름: H0017334, 색상: 7, 선형: Continuous
# 레이어 이름: A0013111, 색상: 1, 선형: Continuous
# 레이어 이름: A0013113, 색상: 1, 선형: Continuous
# 레이어 이름: A0013114, 색상: 1, 선형: Continuous
# 레이어 이름: A0013116, 색상: 1, 선형: Continuous
# 레이어 이름: A0013117, 색상: 1, 선형: Continuous
# 레이어 이름: A0013118, 색상: 1, 선형: Continuous
# 레이어 이름: A0023119, 색상: 1, 선형: Continuous
# 레이어 이름: A0023211, 색상: 7, 선형: Continuous
# 레이어 이름: A0023213, 색상: 7, 선형: Continuous
# 레이어 이름: A0023214, 색상: 7, 선형: Continuous
# 레이어 이름: A0023216, 색상: 7, 선형: Continuous
# 레이어 이름: A0023217, 색상: 7, 선형: Continuous
# 레이어 이름: A0033324, 색상: 1, 선형: Continuous
# 레이어 이름: B0014114, 색상: 7, 선형: Continuous
# 레이어 이름: B0014219, 색상: 7, 선형: Continuous
# 레이어 이름: B0014511, 색상: 7, 선형: Continuous
# 레이어 이름: B0014524, 색상: 7, 선형: Continuous
# 레이어 이름: B0024120, 색상: 3, 선형: Continuous
# 레이어 이름: B0024127, 색상: 7, 선형: Continuous
# 레이어 이름: C0032254, 색상: 7, 선형: Continuous
# 레이어 이름: C0052211, 색상: 1, 선형: Continuous
# 레이어 이름: C0052212, 색상: 1, 선형: Continuous
# 레이어 이름: C0052221, 색상: 1, 선형: Continuous
# 레이어 이름: C0052222, 색상: 1, 선형: Continuous
# 레이어 이름: C0052231, 색상: 1, 선형: Continuous
# 레이어 이름: C0052232, 색상: 1, 선형: Continuous
# 레이어 이름: C0062241, 색상: 5, 선형: Continuous
# 레이어 이름: C0062243, 색상: 1, 선형: Continuous
# 레이어 이름: C0076116, 색상: 7, 선형: Continuous
# 레이어 이름: C0076117, 색상: 7, 선형: Continuous
# 레이어 이름: F0027132, 색상: 7, 선형: Continuous
# 레이어 이름: F0027217, 색상: 7, 선형: Continuous
# 레이어 이름: H0027313, 색상: 7, 선형: Continuous
# 레이어 이름: H0049154, 색상: 7, 선형: Continuous
# 레이어 이름: H0049225, 색상: 7, 선형: Continuous
# 레이어 이름: H0059153, 색상: 7, 선형: Continuous
# 레이어 이름: H0049226, 색상: 7, 선형: Continuous
# 레이어 이름: Defpoints, 색상: 7, 선형: Continuous
#
# === 모델 스페이스 엔티티 ===
#
# --- LWPOLYLINE ---
# 샘플 (최대 5개):
# Handle: 6478B, 레이어: H0017334, 닫힘: False
#   좌표: [(155846.16, 555720.47), (155831.39, 552945.73), (155816.63, 550170.99), (155801.88, 547396.27), (155787.13, 544621.56), (153576.47, 544633.6), (151365.81, 544646.23), (149155.15, 544659.44), (146944.48, 544673.24), (144733.81, 544687.63)]...
# Handle: 6478D, 레이어: A0013111, 닫힘: False
#   좌표: [(155729.982, 544621.871), (155737.976, 544635.016), (155745.97, 544648.16), (155761.86, 544672.73), (155787.604, 544710.746)]
# Handle: 6478F, 레이어: A0013111, 닫힘: False
#   좌표: [(155787.604, 544710.746), (155787.604, 544710.746)]
# Handle: 64790, 레이어: A0013111, 닫힘: False
#   좌표: [(155775.077, 544621.626), (155775.077, 544621.626)]
# Handle: 64791, 레이어: A0013111, 닫힘: False
#   좌표: [(155787.229, 544640.138), (155778.91, 544627.28), (155775.077, 544621.626)]
# 총 LWPOLYLINE 개수: 24958
#
# --- TEXT ---
# 샘플 (최대 5개):
# Handle: 6632C, 레이어: H0049114, 텍스트: 시모도연도교
#   삽입 위치: (148441.087, 548685.558), 높이: 33.0, 회전: 0
# Handle: 6632E, 레이어: H0049114, 텍스트: 신시도연도교
#   삽입 위치: (149963.98, 547965.586), 높이: 33.0, 회전: 0
# Handle: 6632F, 레이어: H0049114, 텍스트: 백년육교
#   삽입 위치: (155757.174, 545401.197), 높이: 33.0, 회전: 0
# Handle: 66330, 레이어: H0049114, 텍스트: 길화교
#   삽입 위치: (153309.091, 557996.946), 높이: 33.0, 회전: 0
# Handle: 6871C, 레이어: H0049140, 텍스트: 북도면사무소
#   삽입 위치: (149368.769, 548265.422), 높이: 33.0, 회전: 0
# 총 TEXT 개수: 1137
#
# --- INSERT ---
# 샘플 (최대 5개):
# Handle: 6871F, 레이어: B0014219, 블록 이름: b0014219
#   삽입 위치: (149368.769, 548265.422), 스케일: (1, 1, 1), 회전: 0
# Handle: 68727, 레이어: B0014511, 블록 이름: B0014511
#   삽입 위치: (145553.61, 557311.454), 스케일: (1, 1, 1), 회전: 0
# Handle: 68731, 레이어: B0014524, 블록 이름: b0014524
#   삽입 위치: (155599.55, 545815.147), 스케일: (1, 1, 1), 회전: 0
# Handle: 69341, 레이어: C0096311, 블록 이름: c0096311
#   삽입 위치: (145882.758, 557770.688), 스케일: (1, 1, 1), 회전: 0
# Handle: 6934B, 레이어: C0096311, 블록 이름: c0096311
#   삽입 위치: (146250.801, 556837.913), 스케일: (1, 1, 1), 회전: 0
# 총 INSERT 개수: 3528
#
# === 블록 목록 (총 {len(list(doc.blocks))}개) ===
#
# 블록 이름: *Model_Space
#   포함 엔티티 수: 29623
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LWPOLYLINE, 레이어: H0017334
#     좌표: [(155846.16, 555720.47), (155831.39, 552945.73), (155816.63, 550170.99), (155801.88, 547396.27), (155787.13, 544621.56)]...
#   - 엔티티 2: 타입: LWPOLYLINE, 레이어: A0013111
#     좌표: [(155729.982, 544621.871), (155737.976, 544635.016), (155745.97, 544648.16), (155761.86, 544672.73), (155787.604, 544710.746)]
#   - 엔티티 3: 타입: LWPOLYLINE, 레이어: A0013111
#     좌표: [(155787.604, 544710.746), (155787.604, 544710.746)]
#   - 엔티티 4: 타입: LWPOLYLINE, 레이어: A0013111
#     좌표: [(155775.077, 544621.626), (155775.077, 544621.626)]
#   - 엔티티 5: 타입: LWPOLYLINE, 레이어: A0013111
#     좌표: [(155787.229, 544640.138), (155778.91, 544627.28), (155775.077, 544621.626)]
#
# 블록 이름: *Paper_Space
#   포함 엔티티 수: 1
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: VIEWPORT, 레이어: 0
#
# 블록 이름: g0022322
#   포함 엔티티 수: 78
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: CIRCLE, 레이어: G0022322
#   - 엔티티 2: 타입: CIRCLE, 레이어: G0022322
#   - 엔티티 3: 타입: CIRCLE, 레이어: G0022322
#   - 엔티티 4: 타입: CIRCLE, 레이어: G0022322
#   - 엔티티 5: 타입: CIRCLE, 레이어: G0022322
#
# 블록 이름: g0022321
#   포함 엔티티 수: 78
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: CIRCLE, 레이어: G0022321
#   - 엔티티 2: 타입: CIRCLE, 레이어: G0022321
#   - 엔티티 3: 타입: CIRCLE, 레이어: G0022321
#   - 엔티티 4: 타입: CIRCLE, 레이어: G0022321
#   - 엔티티 5: 타입: CIRCLE, 레이어: G0022321
#
# 블록 이름: f0027217
#   포함 엔티티 수: 2
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LINE, 레이어: F0027217
#   - 엔티티 2: 타입: LINE, 레이어: F0027217
#
# 블록 이름: g0022324
#   포함 엔티티 수: 9
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: CIRCLE, 레이어: G0022324
#   - 엔티티 2: 타입: CIRCLE, 레이어: G0022324
#   - 엔티티 3: 타입: CIRCLE, 레이어: G0022324
#   - 엔티티 4: 타입: CIRCLE, 레이어: G0022324
#   - 엔티티 5: 타입: CIRCLE, 레이어: G0022324
#
# 블록 이름: g0022323
#   포함 엔티티 수: 7
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LINE, 레이어: G0022323
#   - 엔티티 2: 타입: LINE, 레이어: G0022323
#   - 엔티티 3: 타입: LINE, 레이어: G0022323
#   - 엔티티 4: 타입: LINE, 레이어: G0022323
#   - 엔티티 5: 타입: LINE, 레이어: G0022323
#
# 블록 이름: b0014219
#   포함 엔티티 수: 1
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: CIRCLE, 레이어: B0014219
#
# 블록 이름: B0014511
#   포함 엔티티 수: 4
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LWPOLYLINE, 레이어: B0014511
#     좌표: [(16.577, 13.617), (16.577, -13.458)]
#   - 엔티티 2: 타입: LWPOLYLINE, 레이어: B0014511
#     좌표: [(-18.637, 12.263), (-18.637, -13.458)]
#   - 엔티티 3: 타입: LWPOLYLINE, 레이어: B0014511
#     좌표: [(-31.165, -1.274), (-28.996, -6.773), (-21.566, -12.429), (-11.966, -15.471), (0.667, -16.303)]...
#   - 엔티티 4: 타입: LWPOLYLINE, 레이어: B0014511
#     좌표: [(-18.637, -0.936), (16.577, -0.936)]
#
# 블록 이름: b0014524
#   포함 엔티티 수: 8
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LWPOLYLINE, 레이어: B0014524
#     좌표: [(31.547, -12.018), (31.547, 12.982), (-30.953, 12.982), (-30.953, -12.018)]
#   - 엔티티 2: 타입: LWPOLYLINE, 레이어: B0014524
#     좌표: [(-20.993, 0.0), (22.347, 0.0)]
#   - 엔티티 3: 타입: LWPOLYLINE, 레이어: B0014524
#     좌표: [(-18.453, -37.018), (19.047, -37.018)]
#   - 엔티티 4: 타입: LWPOLYLINE, 레이어: B0014524
#     좌표: [(0.0, 0.0), (0.0, -28.428)]
#   - 엔티티 5: 타입: LWPOLYLINE, 레이어: B0014524
#     좌표: [(-30.953, -12.018), (-18.453, -12.018)]
#
# 블록 이름: c0096311
#   포함 엔티티 수: 4
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LINE, 레이어: C0096311
#   - 엔티티 2: 타입: LINE, 레이어: C0096311
#   - 엔티티 3: 타입: LINE, 레이어: C0096311
#   - 엔티티 4: 타입: LINE, 레이어: C0096311
#
# 블록 이름: C0152261
#   포함 엔티티 수: 11
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: ARC, 레이어: C0152261
#   - 엔티티 2: 타입: ARC, 레이어: C0152261
#   - 엔티티 3: 타입: ARC, 레이어: C0152261
#   - 엔티티 4: 타입: ARC, 레이어: C0152261
#   - 엔티티 5: 타입: ARC, 레이어: C0152261
#
# 블록 이름: c0305316
#   포함 엔티티 수: 3
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: CIRCLE, 레이어: C0305316
#   - 엔티티 2: 타입: CIRCLE, 레이어: C0305316
#   - 엔티티 3: 타입: CIRCLE, 레이어: C0305316
#
# 블록 이름: D0015211
#   포함 엔티티 수: 3
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LWPOLYLINE, 레이어: D0015211
#     좌표: [(-25.0, -12.5), (25.0, -12.5)]
#   - 엔티티 2: 타입: LWPOLYLINE, 레이어: D0015211
#     좌표: [(-10.0, -12.5), (-10.0, 12.5)]
#   - 엔티티 3: 타입: LWPOLYLINE, 레이어: D0015211
#     좌표: [(10.0, -12.5), (10.0, 12.5)]
#
# 블록 이름: d0015212
#   포함 엔티티 수: 3
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LINE, 레이어: D0015212
#   - 엔티티 2: 타입: LINE, 레이어: D0015212
#   - 엔티티 3: 타입: LINE, 레이어: D0015212
#
# 블록 이름: d0015213
#   포함 엔티티 수: 2
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: CIRCLE, 레이어: D0015213
#   - 엔티티 2: 타입: LINE, 레이어: D0015213
#
# 블록 이름: e0042326
#   포함 엔티티 수: 5
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LINE, 레이어: E0042326
#   - 엔티티 2: 타입: LINE, 레이어: E0042326
#   - 엔티티 3: 타입: LINE, 레이어: E0042326
#   - 엔티티 4: 타입: LINE, 레이어: E0042326
#   - 엔티티 5: 타입: LINE, 레이어: E0042326
#
# 블록 이름: h0027311
#   포함 엔티티 수: 4
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LINE, 레이어: H0027311
#   - 엔티티 2: 타입: LINE, 레이어: H0027311
#   - 엔티티 3: 타입: LINE, 레이어: H0027311
#   - 엔티티 4: 타입: CIRCLE, 레이어: H0027311
#
# 블록 이름: h0027312
#   포함 엔티티 수: 5
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LINE, 레이어: H0027312
#   - 엔티티 2: 타입: LINE, 레이어: H0027312
#   - 엔티티 3: 타입: CIRCLE, 레이어: H0027312
#   - 엔티티 4: 타입: LINE, 레이어: H0027312
#   - 엔티티 5: 타입: LINE, 레이어: H0027312
#
# 블록 이름: H0027313
#   포함 엔티티 수: 3
#   샘플 엔티티 (최대 5개):
#   - 엔티티 1: 타입: LWPOLYLINE, 레이어: H0027313
#     좌표: [(-22.5, 22.5), (-22.5, -22.5), (22.5, -22.5), (22.5, 22.5)]
#   - 엔티티 2: 타입: LWPOLYLINE, 레이어: H0027313
#     좌표: [(22.5, 22.5), (-22.5, -22.5)]
#   - 엔티티 3: 타입: LWPOLYLINE, 레이어: H0027313
#     좌표: [(-22.5, 22.5), (22.5, -22.5)]

# %%
import ezdxf
import re

def check_road_data(file_path):
    try:
        doc = ezdxf.readfile(file_path)
        msp = doc.modelspace()

        # 1. 도로 관련 TEXT 검색 (키워드: "로", "길", "도로")
        print("\n=== 도로 관련 TEXT (최대 20개) ===")
        road_text_count = 0
        for entity in msp.query("TEXT"):
            text = entity.dxf.text
            if re.search(r"로|길|도로", text):
                print(f"Handle: {entity.dxf.handle}, 레이어: {entity.dxf.layer}, 텍스트: {text}, 위치: ({entity.dxf.insert[0]}, {entity.dxf.insert[1]})")
                road_text_count += 1
                if road_text_count >= 20:
                    break
        print(f"도로 관련 TEXT 총 개수: {road_text_count}")

        # 2. A0013111 레이어의 LWPOLYLINE (도로로 추정, 최대 5개 샘플)
        print("\n=== A0013111 레이어의 LWPOLYLINE (최대 5개) ===")
        lwpoly_count = 0
        for entity in msp.query('LWPOLYLINE[layer=="A0013111"]'):
            coords = [(point[0], point[1]) for point in entity.get_points()]
            print(f"Handle: {entity.dxf.handle}, 닫힘: {entity.closed}, 좌표: {coords[:10]}{'...' if len(coords) > 10 else ''}")
            lwpoly_count += 1
            if lwpoly_count >= 5:
                break
        print(f"A0013111 레이어의 LWPOLYLINE 총 개수: {lwpoly_count}")

        # 3. 도로로 추정되는 레이어 통계
        print("\n=== 레이어별 LWPOLYLINE 개수 (도로 가능성) ===")
        layer_counts = {}
        for entity in msp.query("LWPOLYLINE"):
            layer = entity.dxf.layer
            layer_counts[layer] = layer_counts.get(layer, 0) + 1
        for layer, count in sorted(layer_counts.items(), key=lambda x: x[1], reverse=True)[:10]:
            print(f"레이어: {layer}, LWPOLYLINE 개수: {count}")

    except Exception as e:
        print(f"오류 발생: {e}")

# 사용 예시
file_path = "C:/Users/user/Desktop/인천시공공데이터공모전/376064.dxf"
check_road_data(file_path)
# Out:
# === 도로 관련 TEXT (최대 20개) ===
# Handle: 66330, 레이어: H0049114, 텍스트: 길화교, 위치: (153309.091, 557996.946)
# Handle: 6A78E, 레이어: H0049131, 텍스트: 길 상 1 저 수 지, 위치: (155612.87, 558388.247)
# Handle: 6B902, 레이어: H0049224, 텍스트: 길 상 면, 위치: (154504.257, 556693.756)
# Handle: 6BF79, 레이어: H0049131, 텍스트: 길 정 천, 위치: (153616.555, 554827.435)
# Handle: 6BF85, 레이어: H0059153, 텍스트: 길상산, 위치: (154991.436, 556961.867)
# Handle: 6BFA4, 레이어: H0049226, 텍스트: 구로지, 위치: (150062.14, 547248.253)
# 도로 관련 TEXT 총 개수: 6
#
# === A0013111 레이어의 LWPOLYLINE (최대 5개) ===
# Handle: 6478D, 닫힘: False, 좌표: [(155729.982, 544621.871), (155737.976, 544635.016), (155745.97, 544648.16), (155761.86, 544672.73), (155787.604, 544710.746)]
# Handle: 6478F, 닫힘: False, 좌표: [(155787.604, 544710.746), (155787.604, 544710.746)]
# Handle: 64790, 닫힘: False, 좌표: [(155775.077, 544621.626), (155775.077, 544621.626)]
# Handle: 64791, 닫힘: False, 좌표: [(155787.229, 544640.138), (155778.91, 544627.28), (155775.077, 544621.626)]
# A0013111 레이어의 LWPOLYLINE 총 개수: 4
#
# === 레이어별 LWPOLYLINE 개수 (도로 가능성) ===
# 레이어: B0014116, LWPOLYLINE 개수: 4069
# 레이어: A0023216, LWPOLYLINE 개수: 3288
# 레이어: B0014112, LWPOLYLINE 개수: 2277
# 레이어: B0014111, LWPOLYLINE 개수: 2256
# 레이어: D0025111, LWPOLYLINE 개수: 2228
# 레이어: A0013116, LWPOLYLINE 개수: 1686
# 레이어: C0076116, LWPOLYLINE 개수: 1402
# 레이어: A0023119, LWPOLYLINE 개수: 850
# 레이어: E0022112, LWPOLYLINE 개수: 839
# 레이어: F0047224, LWPOLYLINE 개수: 694

# %%
import ezdxf
import math
import csv
from datetime import datetime

def check_z_and_calculate_slope(file_path, target_layer="A0013111", max_samples=100, save_csv=False):
    try:
        # DXF 파일 열기
        doc = ezdxf.readfile(file_path)
        msp = doc.modelspace()

        print(f"\n=== {target_layer} 레이어의 2D/3D 확인 및 기울기 분석 ===")
        results = []
        lwpoly_count = 0
        has_z_data = False

        # LWPOLYLINE 처리
        for entity in msp.query(f'LWPOLYLINE[layer=="{target_layer}"]'):
            lwpoly_count += 1
            if lwpoly_count > max_samples:
                break

            # 3D 좌표 추출
            points = entity.get_points()  # (x, y) 또는 (x, y, z)
            if not points:
                continue

            # Z 좌표 확인
            has_z = len(points[0]) > 2
            if has_z:
                has_z_data = True

            # 길이와 고도 변화 계산
            total_length = 0.0
            total_height_diff = 0.0

            for i in range(1, len(points)):
                x1, y1 = points[i-1][0], points[i-1][1]
                x2, y2 = points[i][0], points[i][1]
                dx = x2 - x1
                dy = y2 - y1
                segment_length = math.sqrt(dx**2 + dy**2)
                total_length += segment_length

                if has_z:
                    z1, z2 = points[i-1][2], points[i][2]
                    segment_height_diff = z2 - z1
                    total_height_diff += segment_height_diff
                else:
                    segment_height_diff = 0.0

            # 기울기 계산
            if total_length > 0:
                if has_z:
                    slope_percent = (total_height_diff / total_length) * 100
                else:
                    slope_percent = 0.0
                    print(f"경고: Handle {entity.dxf.handle}에 Z 좌표 없음, 기울기 0으로 설정")
            else:
                slope_percent = 0.0
                print(f"경고: Handle {entity.dxf.handle} 길이 0, 기울기 계산 불가")

            # 결과 저장
            result = {
                "handle": entity.dxf.handle,
                "layer": target_layer,
                "length_m": total_length,
                "height_diff_m": total_height_diff if has_z else None,
                "slope_percent": slope_percent,
                "point_count": len(points),
                "has_z": has_z,
                "closed": entity.closed
            }
            results.append(result)

            # 콘솔 출력
            print(f"Handle: {result['handle']}, 3D: {has_z}, 길이: {result['length_m']:.2f}m, "
                  f"고도 변화: {result['height_diff_m'] if has_z else 'N/A'}m, "
                  f"기울기: {result['slope_percent']:.2f}%")

        # 요약
        print(f"\n=== 요약 ===")
        print(f"처리된 LWPOLYLINE 수: {len(results)} (총 {lwpoly_count} 중)")
        print(f"Z 좌표 포함 여부: {'있음' if has_z_data else '없음'}")
        if results:
            avg_length = sum(r["length_m"] for r in results) / len(results)
            avg_slope = sum(r["slope_percent"] for r in results) / len(results)
            print(f"평균 길이: {avg_length:.2f}m")
            print(f"평균 기울기: {avg_slope:.2f}%")
        else:
            print("분석된 도로 데이터 없음")

        # CSV 저장 (옵션)
        if save_csv and results:
            csv_file = f"road_slopes_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
            with open(csv_file, "w", newline="", encoding="utf-8") as f:
                writer = csv.DictWriter(f, fieldnames=results[0].keys())
                writer.writeheader()
                writer.writerows(results)
            print(f"결과가 {csv_file}에 저장되었습니다.")

        return results

    except Exception as e:
        print(f"오류 발생: {e}")
        return None

# 사용 예시
file_path = "C:/Users/user/Desktop/인천시공공데이터공모전/376064.dxf"
check_z_and_calculate_slope(file_path, target_layer="A0013111", max_samples=100, save_csv=False)
# Out:
# === A0013111 레이어의 2D/3D 확인 및 기울기 분석 ===
# Handle: 6478D, 3D: True, 길이: 105.94m, 고도 변화: 0.0m, 기울기: 0.00%
# 경고: Handle 6478F 길이 0, 기울기 계산 불가
# Handle: 6478F, 3D: True, 길이: 0.00m, 고도 변화: 0.0m, 기울기: 0.00%
# 경고: Handle 64790 길이 0, 기울기 계산 불가
# Handle: 64790, 3D: True, 길이: 0.00m, 고도 변화: 0.0m, 기울기: 0.00%
# Handle: 64791, 3D: True, 길이: 22.15m, 고도 변화: 0.0m, 기울기: 0.00%
#
# === 요약 ===
# 처리된 LWPOLYLINE 수: 4 (총 4 중)
# Z 좌표 포함 여부: 있음
# 평균 길이: 32.02m
# 평균 기울기: 0.00%
# [{'handle': '6478D',
#   'layer': 'A0013111',
#   'length_m': 105.94207449344105,
#   'height_diff_m': 0.0,
#   'slope_percent': 0.0,
#   'point_count': 5,
#   'has_z': True,
#   'closed': False},
#  {'handle': '6478F',
#   'layer': 'A0013111',
#   'length_m': 0.0,
#   'height_diff_m': 0.0,
#   'slope_percent': 0.0,
#   'point_count': 2,
#   'has_z': True,
#   'closed': False},
#  {'handle': '64790',
#   'layer': 'A0013111',
#   'length_m': 0.0,
#   'height_diff_m': 0.0,
#   'slope_percent': 0.0,
#   'point_count': 2,
#   'has_z': True,
#   'closed': False},
#  {'handle': '64791',
#   'layer': 'A0013111',
#   'length_m': 22.14528411157014,
#   'height_diff_m': 0.0,
#   'slope_percent': 0.0,
#   'point_count': 3,
#   'has_z': True,
#   'closed': False}]

# %%
import ezdxf
import math
import csv
from datetime import datetime
from collections import defaultdict

def analyze_all_lwpolyline_slopes(file_path, max_samples_per_layer=100, save_csv=False):
    try:
        # DXF 파일 열기
        doc = ezdxf.readfile(file_path)
        msp = doc.modelspace()

        print("\n=== 전체 DXF 파일의 LWPOLYLINE 분석 ===")
        results = []
        layer_stats = defaultdict(lambda: {"count": 0, "has_z": 0, "non_zero_slope": 0, "total_length": 0.0, "total_height_diff": 0.0})
        total_lwpoly_count = 0

        # 모든 LWPOLYLINE 처리
        for entity in msp.query("LWPOLYLINE"):
            layer = entity.dxf.layer
            layer_stats[layer]["count"] += 1
            total_lwpoly_count += 1

            # 레이어별 샘플 제한
            if layer_stats[layer]["count"] > max_samples_per_layer:
                continue

            # 3D 좌표 추출
            points = entity.get_points()
            if not points:
                continue

            # Z 좌표 확인
            has_z = len(points[0]) > 2
            if has_z:
                layer_stats[layer]["has_z"] += 1

            # 길이와 고도 변화 계산
            total_length = 0.0
            total_height_diff = 0.0

            for i in range(1, len(points)):
                x1, y1 = points[i-1][0], points[i-1][1]
                x2, y2 = points[i][0], points[i][1]
                dx = x2 - x1
                dy = y2 - y1
                segment_length = math.sqrt(dx**2 + dy**2)
                total_length += segment_length

                if has_z:
                    z1, z2 = points[i-1][2], points[i][2]
                    segment_height_diff = z2 - z1
                    total_height_diff += segment_height_diff

            # 기울기 계산
            if total_length > 0:
                if has_z:
                    slope_percent = (total_height_diff / total_length) * 100
                else:
                    slope_percent = 0.0
                    print(f"경고: Handle {entity.dxf.handle} (레이어: {layer})에 Z 좌표 없음, 기울기 0으로 설정")
            else:
                slope_percent = 0.0
                print(f"경고: Handle {entity.dxf.handle} (레이어: {layer}) 길이 0, 기울기 계산 불가")

            # 레이어 통계 업데이트
            layer_stats[layer]["total_length"] += total_length
            layer_stats[layer]["total_height_diff"] += total_height_diff if has_z else 0.0
            if slope_percent != 0.0:
                layer_stats[layer]["non_zero_slope"] += 1

            # 결과 저장
            result = {
                "handle": entity.dxf.handle,
                "layer": layer,
                "length_m": total_length,
                "height_diff_m": total_height_diff if has_z else None,
                "slope_percent": slope_percent,
                "point_count": len(points),
                "has_z": has_z,
                "closed": entity.closed
            }
            results.append(result)

            # 샘플 출력 (최대 5개)
            if total_lwpoly_count <= 5:
                print(f"Handle: {result['handle']}, 레이어: {layer}, 3D: {has_z}, "
                      f"길이: {result['length_m']:.2f}m, 고도 변화: {result['height_diff_m'] if has_z else 'N/A'}m, "
                      f"기울기: {result['slope_percent']:.2f}%")

        # 레이어별 요약
        print(f"\n=== 레이어별 요약 (총 LWPOLYLINE: {total_lwpoly_count}) ===")
        for layer, stats in sorted(layer_stats.items(), key=lambda x: x[1]["count"], reverse=True):
            print(f"레이어: {layer}")
            print(f"  LWPOLYLINE 수: {stats['count']}")
            print(f"  Z 좌표 포함: {stats['has_z']} ({stats['has_z']/stats['count']*100:.1f}%)")
            print(f"  비영 기울기(ΔZ≠0): {stats['non_zero_slope']} ({stats['non_zero_slope']/stats['count']*100:.1f}%)")
            print(f"  평균 길이: {stats['total_length']/stats['count']:.2f}m")
            print(f"  평균 고도 변화: {stats['total_height_diff']/stats['count']:.2f}m" if stats['has_z'] > 0 else "  고도 변화: N/A")

        # 전체 요약
        print(f"\n=== 전체 요약 ===")
        print(f"총 처리된 LWPOLYLINE: {len(results)} (총 {total_lwpoly_count} 중)")
        z_count = sum(1 for r in results if r["has_z"])
        non_zero_slope_count = sum(1 for r in results if r["slope_percent"] != 0.0)
        print(f"Z 좌표 포함 LWPOLYLINE: {z_count} ({z_count/len(results)*100:.1f}%)")
        print(f"비영 기울기 LWPOLYLINE: {non_zero_slope_count} ({non_zero_slope_count/len(results)*100:.1f}%)")
        if results:
            avg_length = sum(r["length_m"] for r in results) / len(results)
            avg_slope = sum(r["slope_percent"] for r in results) / len(results)
            print(f"평균 길이: {avg_length:.2f}m")
            print(f"평균 기울기: {avg_slope:.2f}%")

        # CSV 저장 (옵션)
        if save_csv and results:
            csv_file = f"all_lwpoly_slopes_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
            with open(csv_file, "w", newline="", encoding="utf-8") as f:
                writer = csv.DictWriter(f, fieldnames=results[0].keys())
                writer.writeheader()
                writer.writerows(results)
            print(f"결과가 {csv_file}에 저장되었습니다.")

        return results, layer_stats

    except Exception as e:
        print(f"오류 발생: {e}")
        return None, None

# 사용 예시
file_path = "C:/Users/user/Desktop/인천시공공데이터공모전/376064.dxf"
results, layer_stats = analyze_all_lwpolyline_slopes(file_path, max_samples_per_layer=100, save_csv=False)
# Out:
# === 전체 DXF 파일의 LWPOLYLINE 분석 ===
# Handle: 6478B, 레이어: H0017334, 3D: True, 길이: 49836.50m, 고도 변화: 0.0m, 기울기: 0.00%
# Handle: 6478D, 레이어: A0013111, 3D: True, 길이: 105.94m, 고도 변화: 0.0m, 기울기: 0.00%
# 경고: Handle 6478F (레이어: A0013111) 길이 0, 기울기 계산 불가
# Handle: 6478F, 레이어: A0013111, 3D: True, 길이: 0.00m, 고도 변화: 0.0m, 기울기: 0.00%
# 경고: Handle 64790 (레이어: A0013111) 길이 0, 기울기 계산 불가
# Handle: 64790, 레이어: A0013111, 3D: True, 길이: 0.00m, 고도 변화: 0.0m, 기울기: 0.00%
# Handle: 64791, 레이어: A0013111, 3D: True, 길이: 22.15m, 고도 변화: 0.0m, 기울기: 0.00%
# 경고: Handle 64792 (레이어: A0013113) 길이 0, 기울기 계산 불가
# 경고: Handle 647D8 (레이어: A0013114) 길이 0, 기울기 계산 불가
# 경고: Handle 647E5 (레이어: A0013114) 길이 0, 기울기 계산 불가
# 경고: Handle 647E6 (레이어: A0013114) 길이 0, 기울기 계산 불가
# 경고: Handle 647E7 (레이어: A0013114) 길이 0, 기울기 계산 불가
# 경고: Handle 647E8 (레이어: A0013114) 길이 0, 기울기 계산 불가
# 경고: Handle 647E9 (레이어: A0013114) 길이 0, 기울기 계산 불가
# 경고: Handle 647EA (레이어: A0013114) 길이 0, 기울기 계산 불가
# 경고: Handle 647EB (레이어: A0013114) 길이 0, 기울기 계산 불가
# 경고: Handle 647ED (레이어: A0013114) 길이 0, 기울기 계산 불가
# 경고: Handle 647F9 (레이어: A0013114) 길이 0, 기울기 계산 불가
# 경고: Handle 647FC (레이어: A0013114) 길이 0, 기울기 계산 불가
# 경고: Handle 64EE5 (레이어: A0013117) 길이 0, 기울기 계산 불가
# 경고: Handle 64EE6 (레이어: A0013117) 길이 0, 기울기 계산 불가
# 경고: Handle 64EF0 (레이어: A0013117) 길이 0, 기울기 계산 불가
# 경고: Handle 64EF1 (레이어: A0013117) 길이 0, 기울기 계산 불가
# 경고: Handle 64F22 (레이어: A0013118) 길이 0, 기울기 계산 불가
# 경고: Handle 64F29 (레이어: A0013118) 길이 0, 기울기 계산 불가
# 경고: Handle 68A48 (레이어: C0052212) 길이 0, 기울기 계산 불가
# 경고: Handle 68B2A (레이어: C0052231) 길이 0, 기울기 계산 불가
# 경고: Handle 68B2B (레이어: C0052231) 길이 0, 기울기 계산 불가
# 경고: Handle 68B49 (레이어: C0052232) 길이 0, 기울기 계산 불가
# 경고: Handle 6911F (레이어: C0076117) 길이 0, 기울기 계산 불가
# 경고: Handle 69120 (레이어: C0076117) 길이 0, 기울기 계산 불가
# 경고: Handle 69121 (레이어: C0076117) 길이 0, 기울기 계산 불가
# 경고: Handle 6A7F0 (레이어: E0082122) 길이 0, 기울기 계산 불가
# 경고: Handle 6A7F2 (레이어: E0082122) 길이 0, 기울기 계산 불가
# 경고: Handle 6A826 (레이어: F0017111) 길이 0, 기울기 계산 불가
# 경고: Handle 6A837 (레이어: F0017111) 길이 0, 기울기 계산 불가
# 경고: Handle 6A849 (레이어: F0017111) 길이 0, 기울기 계산 불가
# 경고: Handle 6A84D (레이어: F0017111) 길이 0, 기울기 계산 불가
# 경고: Handle 6A84F (레이어: F0017111) 길이 0, 기울기 계산 불가
# 경고: Handle 6A851 (레이어: F0017111) 길이 0, 기울기 계산 불가
# 경고: Handle 6A9BC (레이어: F0017114) 길이 0, 기울기 계산 불가
# 경고: Handle 6A9C2 (레이어: F0017114) 길이 0, 기울기 계산 불가
# 경고: Handle 6A9C8 (레이어: F0017114) 길이 0, 기울기 계산 불가
# 경고: Handle 6A9CB (레이어: F0017114) 길이 0, 기울기 계산 불가
# 경고: Handle 6A9E6 (레이어: F0017114) 길이 0, 기울기 계산 불가
#
# === 레이어별 요약 (총 LWPOLYLINE: 24958) ===
# 레이어: B0014116
#   LWPOLYLINE 수: 4069
#   Z 좌표 포함: 100 (2.5%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 0.38m
#   평균 고도 변화: 0.00m
# 레이어: A0023216
#   LWPOLYLINE 수: 3288
#   Z 좌표 포함: 100 (3.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 2.96m
#   평균 고도 변화: 0.00m
# 레이어: B0014112
#   LWPOLYLINE 수: 2277
#   Z 좌표 포함: 100 (4.4%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 2.05m
#   평균 고도 변화: 0.00m
# 레이어: B0014111
#   LWPOLYLINE 수: 2256
#   Z 좌표 포함: 100 (4.4%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 2.81m
#   평균 고도 변화: 0.00m
# 레이어: D0025111
#   LWPOLYLINE 수: 2228
#   Z 좌표 포함: 100 (4.5%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 7.87m
#   평균 고도 변화: 0.00m
# 레이어: A0013116
#   LWPOLYLINE 수: 1686
#   Z 좌표 포함: 100 (5.9%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 26.91m
#   평균 고도 변화: 0.00m
# 레이어: C0076116
#   LWPOLYLINE 수: 1402
#   Z 좌표 포함: 100 (7.1%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 0.49m
#   평균 고도 변화: 0.00m
# 레이어: A0023119
#   LWPOLYLINE 수: 850
#   Z 좌표 포함: 100 (11.8%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 10.32m
#   평균 고도 변화: 0.00m
# 레이어: E0022112
#   LWPOLYLINE 수: 839
#   Z 좌표 포함: 100 (11.9%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 15.90m
#   평균 고도 변화: 0.00m
# 레이어: F0047224
#   LWPOLYLINE 수: 694
#   Z 좌표 포함: 100 (14.4%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 8.89m
#   평균 고도 변화: 0.00m
# 레이어: C0076117
#   LWPOLYLINE 수: 616
#   Z 좌표 포함: 100 (16.2%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 21.21m
#   평균 고도 변화: 0.00m
# 레이어: B0014118
#   LWPOLYLINE 수: 486
#   Z 좌표 포함: 100 (20.6%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 3.20m
#   평균 고도 변화: 0.00m
# 레이어: F0017111
#   LWPOLYLINE 수: 449
#   Z 좌표 포함: 100 (22.3%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 258.39m
#   평균 고도 변화: 0.00m
# 레이어: C0052211
#   LWPOLYLINE 수: 396
#   Z 좌표 포함: 100 (25.3%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 26.35m
#   평균 고도 변화: 0.00m
# 레이어: A0013118
#   LWPOLYLINE 수: 351
#   Z 좌표 포함: 100 (28.5%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 27.95m
#   평균 고도 변화: 0.00m
# 레이어: B0024120
#   LWPOLYLINE 수: 286
#   Z 좌표 포함: 100 (35.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 29.49m
#   평균 고도 변화: 0.00m
# 레이어: A0023217
#   LWPOLYLINE 수: 251
#   Z 좌표 포함: 100 (39.8%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 35.27m
#   평균 고도 변화: 0.00m
# 레이어: G0022314
#   LWPOLYLINE 수: 197
#   Z 좌표 포함: 100 (50.8%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 46.59m
#   평균 고도 변화: 0.00m
# 레이어: A0033324
#   LWPOLYLINE 수: 177
#   Z 좌표 포함: 100 (56.5%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 150.02m
#   평균 고도 변화: 0.00m
# 레이어: E0052114
#   LWPOLYLINE 수: 177
#   Z 좌표 포함: 100 (56.5%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 100.00m
#   평균 고도 변화: 0.00m
# 레이어: G0037213
#   LWPOLYLINE 수: 170
#   Z 좌표 포함: 100 (58.8%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 100.48m
#   평균 고도 변화: 0.00m
# 레이어: F0037223
#   LWPOLYLINE 수: 110
#   Z 좌표 포함: 100 (90.9%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 85.20m
#   평균 고도 변화: 0.00m
# 레이어: A0013114
#   LWPOLYLINE 수: 106
#   Z 좌표 포함: 100 (94.3%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 183.70m
#   평균 고도 변화: 0.00m
# 레이어: E0022115
#   LWPOLYLINE 수: 103
#   Z 좌표 포함: 100 (97.1%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 384.14m
#   평균 고도 변화: 0.00m
# 레이어: F0037222
#   LWPOLYLINE 수: 103
#   Z 좌표 포함: 100 (97.1%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 98.84m
#   평균 고도 변화: 0.00m
# 레이어: F0017114
#   LWPOLYLINE 수: 93
#   Z 좌표 포함: 93 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 2681.29m
#   평균 고도 변화: 0.00m
# 레이어: A0043325
#   LWPOLYLINE 수: 88
#   Z 좌표 포함: 88 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 28.70m
#   평균 고도 변화: 0.00m
# 레이어: C0052221
#   LWPOLYLINE 수: 88
#   Z 좌표 포함: 88 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 378.72m
#   평균 고도 변화: 0.00m
# 레이어: A0013117
#   LWPOLYLINE 수: 87
#   Z 좌표 포함: 87 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 86.85m
#   평균 고도 변화: 0.00m
# 레이어: G0022312
#   LWPOLYLINE 수: 86
#   Z 좌표 포함: 86 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 505.89m
#   평균 고도 변화: 0.00m
# 레이어: A0023214
#   LWPOLYLINE 수: 79
#   Z 좌표 포함: 79 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 137.08m
#   평균 고도 변화: 0.00m
# 레이어: C0052231
#   LWPOLYLINE 수: 76
#   Z 좌표 포함: 76 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 140.75m
#   평균 고도 변화: 0.00m
# 레이어: E0082122
#   LWPOLYLINE 수: 70
#   Z 좌표 포함: 70 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 714.36m
#   평균 고도 변화: 0.00m
# 레이어: C0052222
#   LWPOLYLINE 수: 60
#   Z 좌표 포함: 60 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 471.25m
#   평균 고도 변화: 0.00m
# 레이어: E0032111
#   LWPOLYLINE 수: 49
#   Z 좌표 포함: 49 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 1922.67m
#   평균 고도 변화: 0.00m
# 레이어: G0022311
#   LWPOLYLINE 수: 49
#   Z 좌표 포함: 49 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 3863.03m
#   평균 고도 변화: 0.00m
# 레이어: A0073340
#   LWPOLYLINE 수: 47
#   Z 좌표 포함: 47 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 73.02m
#   평균 고도 변화: 0.00m
# 레이어: G0022313
#   LWPOLYLINE 수: 45
#   Z 좌표 포함: 45 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 392.96m
#   평균 고도 변화: 0.00m
# 레이어: B0014115
#   LWPOLYLINE 수: 44
#   Z 좌표 포함: 44 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 130.58m
#   평균 고도 변화: 0.00m
# 레이어: C0052212
#   LWPOLYLINE 수: 43
#   Z 좌표 포함: 43 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 200.68m
#   평균 고도 변화: 0.00m
# 레이어: G0037214
#   LWPOLYLINE 수: 41
#   Z 좌표 포함: 41 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 240.27m
#   평균 고도 변화: 0.00m
# 레이어: B0014117
#   LWPOLYLINE 수: 38
#   Z 좌표 포함: 38 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 58.49m
#   평균 고도 변화: 0.00m
# 레이어: G0018112
#   LWPOLYLINE 수: 38
#   Z 좌표 포함: 38 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 1843.14m
#   평균 고도 변화: 0.00m
# 레이어: F0047225
#   LWPOLYLINE 수: 34
#   Z 좌표 포함: 34 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 51.29m
#   평균 고도 변화: 0.00m
# 레이어: E0082121
#   LWPOLYLINE 수: 32
#   Z 좌표 포함: 32 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 626.06m
#   평균 고도 변화: 0.00m
# 레이어: C0052232
#   LWPOLYLINE 수: 30
#   Z 좌표 포함: 30 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 166.32m
#   평균 고도 변화: 0.00m
# 레이어: B0024127
#   LWPOLYLINE 수: 25
#   Z 좌표 포함: 25 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 11.61m
#   평균 고도 변화: 0.00m
# 레이어: A0033327
#   LWPOLYLINE 수: 22
#   Z 좌표 포함: 22 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 148.49m
#   평균 고도 변화: 0.00m
# 레이어: C0393323
#   LWPOLYLINE 수: 21
#   Z 좌표 포함: 21 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 123.34m
#   평균 고도 변화: 0.00m
# 레이어: C0032254
#   LWPOLYLINE 수: 15
#   Z 좌표 포함: 15 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 232.11m
#   평균 고도 변화: 0.00m
# 레이어: C0523121
#   LWPOLYLINE 수: 13
#   Z 좌표 포함: 13 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 264.58m
#   평균 고도 변화: 0.00m
# 레이어: A0053326
#   LWPOLYLINE 수: 8
#   Z 좌표 포함: 8 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 241.55m
#   평균 고도 변화: 0.00m
# 레이어: C0062241
#   LWPOLYLINE 수: 8
#   Z 좌표 포함: 8 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 22.10m
#   평균 고도 변화: 0.00m
# 레이어: G0018117
#   LWPOLYLINE 수: 8
#   Z 좌표 포함: 8 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 707.42m
#   평균 고도 변화: 0.00m
# 레이어: C0062243
#   LWPOLYLINE 수: 7
#   Z 좌표 포함: 7 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 19.62m
#   평균 고도 변화: 0.00m
# 레이어: F0037221
#   LWPOLYLINE 수: 7
#   Z 좌표 포함: 7 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 93.99m
#   평균 고도 변화: 0.00m
# 레이어: G0038232
#   LWPOLYLINE 수: 6
#   Z 좌표 포함: 6 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 182.89m
#   평균 고도 변화: 0.00m
# 레이어: A0013113
#   LWPOLYLINE 수: 5
#   Z 좌표 포함: 5 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 224.55m
#   평균 고도 변화: 0.00m
# 레이어: B0014114
#   LWPOLYLINE 수: 5
#   Z 좌표 포함: 5 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 72.86m
#   평균 고도 변화: 0.00m
# 레이어: A0013111
#   LWPOLYLINE 수: 4
#   Z 좌표 포함: 4 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 32.02m
#   평균 고도 변화: 0.00m
# 레이어: A0160024
#   LWPOLYLINE 수: 4
#   Z 좌표 포함: 4 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 73.31m
#   평균 고도 변화: 0.00m
# 레이어: C0390130
#   LWPOLYLINE 수: 4
#   Z 좌표 포함: 4 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 71.31m
#   평균 고도 변화: 0.00m
# 레이어: A0151116
#   LWPOLYLINE 수: 3
#   Z 좌표 포함: 3 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 130.96m
#   평균 고도 변화: 0.00m
# 레이어: A0063321
#   LWPOLYLINE 수: 2
#   Z 좌표 포함: 2 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 261.48m
#   평균 고도 변화: 0.00m
# 레이어: B0014113
#   LWPOLYLINE 수: 2
#   Z 좌표 포함: 2 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 52.75m
#   평균 고도 변화: 0.00m
# 레이어: H0017334
#   LWPOLYLINE 수: 1
#   Z 좌표 포함: 1 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 49836.50m
#   평균 고도 변화: 0.00m
# 레이어: A0023211
#   LWPOLYLINE 수: 1
#   Z 좌표 포함: 1 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 64.24m
#   평균 고도 변화: 0.00m
# 레이어: A0023213
#   LWPOLYLINE 수: 1
#   Z 좌표 포함: 1 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 599.16m
#   평균 고도 변화: 0.00m
# 레이어: C0295113
#   LWPOLYLINE 수: 1
#   Z 좌표 포함: 1 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 306.58m
#   평균 고도 변화: 0.00m
# 레이어: G0038231
#   LWPOLYLINE 수: 1
#   Z 좌표 포함: 1 (100.0%)
#   비영 기울기(ΔZ≠0): 0 (0.0%)
#   평균 길이: 185.27m
#   평균 고도 변화: 0.00m
#
# === 전체 요약 ===
# 총 처리된 LWPOLYLINE: 3891 (총 24958 중)
# Z 좌표 포함 LWPOLYLINE: 3891 (100.0%)
# 비영 기울기 LWPOLYLINE: 0 (0.0%)
# 평균 길이: 352.68m
# 평균 기울기: 0.00%

# %%
import ezdxf
import pandas as pd
import math

file_path = 'C:/Users/user/Desktop/인천시공공데이터공모전/376064.dxf'

# DXF 파일 열기
doc = ezdxf.readfile(file_path)
msp = doc.modelspace()

# 모든 엔티티 추출
entities_data = []
for entity in msp:
    entity_type = entity.dxftype()
    if entity_type == "LINE":
        start_x, start_y, start_z = entity.dxf.start[0], entity.dxf.start[1], entity.dxf.start[2]
        end_x, end_y, end_z = entity.dxf.end[0], entity.dxf.end[1], entity.dxf.end[2]
        dx = end_x - start_x
        dy = end_y - start_y
        dz = end_z - start_z
        angle = math.degrees(math.atan2(dy, dx))
        elevation_change = end_z - start_z
        entities_data.append({
            "type": "LINE",
            "start_x": start_x,
            "start_y": start_y,
            "start_z": start_z,
            "end_x": end_x,
            "end_y": end_y,
            "end_z": end_z,
            "angle": f"{angle:.2f} degrees",
            "elevation_change": f"{elevation_change:.2f} units",
            "extra": ""
        })
    elif entity_type == "CIRCLE":
        entities_data.append({
            "type": "CIRCLE",
            "start_x": entity.dxf.center[0],
            "start_y": entity.dxf.center[1],
            "start_z": entity.dxf.center[2],
            "end_x": "",
            "end_y": "",
            "end_z": "",
            "angle": "",
            "elevation_change": "",
            "extra": f"radius: {entity.dxf.radius}"
        })
    elif entity_type == "ARC":
        entities_data.append({
            "type": "ARC",
            "start_x": entity.dxf.center[0],
            "start_y": entity.dxf.center[1],
            "start_z": entity.dxf.center[2],
            "end_x": "",
            "end_y": "",
            "end_z": "",
            "angle": f"start: {entity.dxf.start_angle}, end: {entity.dxf.end_angle}",
            "elevation_change": "",
            "extra": f"radius: {entity.dxf.radius}"
        })
    elif entity_type == "TEXT":
        entities_data.append({
            "type": "TEXT",
            "start_x": entity.dxf.insert[0],
            "start_y": entity.dxf.insert[1],
            "start_z": entity.dxf.insert[2],
            "end_x": "",
            "end_y": "",
            "end_z": "",
            "angle": "",
            "elevation_change": "",
            "extra": f"text: {entity.dxf.text}"
        })
    elif entity_type == "MTEXT":
        entities_data.append({
            "type": "MTEXT",
            "start_x": entity.dxf.insert[0],
            "start_y": entity.dxf.insert[1],
            "start_z": entity.dxf.insert[2],
            "end_x": "",
            "end_y": "",
            "end_z": "",
            "angle": "",
            "elevation_change": "",
            "extra": f"text: {entity.text}"
        })
    elif entity_type == "LWPOLYLINE":
        elevation = entity.dxf.get("elevation", 0)
        vertices = list(entity.get_points("xy"))
        for i in range(len(vertices)):
            start = vertices[i]
            end = vertices[(i + 1) % len(vertices)]
            dx = end[0] - start[0]
            dy = end[1] - start[1]
            angle = math.degrees(math.atan2(dy, dx))
            entities_data.append({
                "type": "LWPOLYLINE",
                "start_x": start[0],
                "start_y": start[1],
                "start_z": elevation,
                "end_x": end[0],
                "end_y": end[1],
                "end_z": elevation,
                "angle": f"{angle:.2f} degrees",
                "elevation_change": "0.00 units",
                "extra": ""
            })
    else:
        entities_data.append({
            "type": entity_type,
            "start_x": "",
            "start_y": "",
            "start_z": "",
            "end_x": "",
            "end_y": "",
            "end_z": "",
            "angle": "",
            "elevation_change": "",
            "extra": "Unsupported entity"
        })

# 데이터프레임으로 변환
df_entities = pd.DataFrame(entities_data)

# CSV로 저장
'''
df_entities.to_csv("dxf_entities_extracted.csv", index=False)
'''
# 결과 출력
print("✅ DXF 데이터 추출 완료. CSV 파일로 저장되었습니다.")
print(df_entities.head())
# Out:
# ✅ DXF 데이터 추출 완료. CSV 파일로 저장되었습니다.
#          type    start_x    start_y start_z      end_x      end_y end_z  \
# 0  LWPOLYLINE  155846.16  555720.47       0  155831.39  552945.73     0
# 1  LWPOLYLINE  155831.39  552945.73       0  155816.63  550170.99     0
# 2  LWPOLYLINE  155816.63  550170.99       0  155801.88  547396.27     0
# 3  LWPOLYLINE  155801.88  547396.27       0  155787.13  544621.56     0
# 4  LWPOLYLINE  155787.13  544621.56       0  153576.47   544633.6     0
#
#             angle elevation_change extra
# 0  -90.30 degrees       0.00 units
# 1  -90.30 degrees       0.00 units
# 2  -90.30 degrees       0.00 units
# 3  -90.30 degrees       0.00 units
# 4  179.69 degrees       0.00 units

# %%
import ezdxf

def extract_elevation_from_dxf(file_path):
    try:
        # DXF 파일 로드
        doc = ezdxf.readfile(file_path)
        msp = doc.modelspace()

        # 결과를 저장할 리스트
        elevations = []

        # 1. 3D 폴리라인에서 Z-좌표(고도) 추출
        for entity in msp.query('POLYLINE'):
            if entity.is_3d_polyline:
                for vertex in entity.vertices():
                    z_coord = vertex.dxf.location[2]  # Z-좌표 추출
                    elevations.append({
                        'type': '3D Polyline',
                        'x': vertex.dxf.location[0],
                        'y': vertex.dxf.location[1],
                        'elevation': z_coord
                    })

        # 2. 텍스트 엔티티에서 고도 데이터 추출
        for entity in msp.query('TEXT MTEXT'):
            text = entity.dxf.text
            try:
                # 텍스트가 숫자(고도)로 변환 가능한 경우
                elevation = float(text)
                elevations.append({
                    'type': 'Text',
                    'x': entity.dxf.insert[0],
                    'y': entity.dxf.insert[1],
                    'elevation': elevation
                })
            except ValueError:
                continue  # 숫자로 변환 불가능하면 무시

        # 3. 속성(ATTRIB)에서 고도 데이터 추출
        for entity in msp.query('INSERT'):
            try:
                # attribs 속성이 있는지 확인
                if hasattr(entity, 'attribs') and entity.attribs:
                    for attrib in entity.attribs:
                        try:
                            elevation = float(attrib.dxf.text)
                            elevations.append({
                                'type': 'Attribute',
                                'x': entity.dxf.insert[0],
                                'y': entity.dxf.insert[1],
                                'elevation': elevation
                            })
                        except ValueError:
                            continue  # 숫자로 변환 불가능하면 무시
            except AttributeError:
                continue  # attribs 속성이 없으면 무시

        return elevations

    except Exception as e:
        print(f"Error reading DXF file: {e}")
        return []

# 사용 예시
file_path = 'C:/Users/user/Desktop/인천시공공데이터공모전/376064.dxf'  # DXF 파일 경로
elevations = extract_elevation_from_dxf(file_path)

# 결과 출력
for elev in elevations:
    print(f"Type: {elev['type']}, X: {elev['x']}, Y: {elev['y']}, Elevation: {elev['elevation']}")
# Out:
# Type: Text, X: 149737.582, Y: 546682.499, Elevation: 50.0
# Type: Text, X: 153060.276, Y: 548051.01, Elevation: 50.0
# Type: Text, X: 151795.944, Y: 548050.37, Elevation: 100.0
# Type: Text, X: 151632.231, Y: 547903.414, Elevation: 100.0
# Type: Text, X: 151859.561, Y: 544701.828, Elevation: 0.0
# Type: Text, X: 144884.689, Y: 548715.07, Elevation: 50.0
# Type: Text, X: 145206.405, Y: 548316.524, Elevation: 100.0
# Type: Text, X: 147444.606, Y: 557181.616, Elevation: 250.0
# Type: Text, X: 147522.12, Y: 557816.766, Elevation: 150.0
# Type: Text, X: 147290.315, Y: 558047.608, Elevation: 150.0
# Type: Text, X: 152123.229, Y: 555476.751, Elevation: 100.0
# Type: Text, X: 145573.953, Y: 548417.779, Elevation: 0.0
# Type: Text, X: 150561.878, Y: 547286.298, Elevation: 100.0
# Type: Text, X: 149122.915, Y: 547944.53, Elevation: 100.0
# Type: Text, X: 150983.889, Y: 547475.989, Elevation: 150.0
# Type: Text, X: 152216.177, Y: 547400.574, Elevation: 50.0
# Type: Text, X: 148949.352, Y: 547639.53, Elevation: 50.0
# Type: Text, X: 148210.253, Y: 549167.356, Elevation: 0.0
# Type: Text, X: 151249.782, Y: 547831.738, Elevation: 150.0
# Type: Text, X: 149227.596, Y: 549584.071, Elevation: 50.0
# Type: Text, X: 155467.219, Y: 544771.395, Elevation: 57.6
# Type: Text, X: 155445.72, Y: 545718.714, Elevation: 6.7
# Type: Text, X: 155752.807, Y: 544862.132, Elevation: 9.5
# Type: Text, X: 155665.342, Y: 545132.681, Elevation: 10.6
# Type: Text, X: 155672.108, Y: 545281.677, Elevation: 8.3
# Type: Text, X: 155787.284, Y: 545732.509, Elevation: 6.4
# Type: Text, X: 155470.596, Y: 545402.121, Elevation: 8.7
# Type: Text, X: 155684.966, Y: 545461.067, Elevation: 6.9
# Type: Text, X: 155710.113, Y: 545605.267, Elevation: 6.8
# Type: Text, X: 148008.798, Y: 547713.774, Elevation: 8.6
# Type: Text, X: 147940.007, Y: 547882.655, Elevation: 2.6
# Type: Text, X: 149127.759, Y: 547162.049, Elevation: 1.7
# Type: Text, X: 147954.359, Y: 548018.657, Elevation: 6.7
# Type: Text, X: 148043.957, Y: 548163.99, Elevation: 6.5
# Type: Text, X: 148816.864, Y: 548301.645, Elevation: 2.1
# Type: Text, X: 149106.34, Y: 548214.708, Elevation: 57.0
# Type: Text, X: 148776.773, Y: 547769.174, Elevation: 41.4
# Type: Text, X: 148663.32, Y: 547910.541, Elevation: 1.5
# Type: Text, X: 148714.859, Y: 547566.298, Elevation: 2.7
# Type: Text, X: 149022.082, Y: 547582.008, Elevation: 41.8
# Type: Text, X: 149090.489, Y: 547820.007, Elevation: 102.2
# Type: Text, X: 148391.44, Y: 547170.16, Elevation: 1.7
# Type: Text, X: 148421.155, Y: 547299.501, Elevation: 1.4
# Type: Text, X: 148676.684, Y: 547187.774, Elevation: 1.8
# Type: Text, X: 148857.967, Y: 547323.865, Elevation: 53.9
# Type: Text, X: 149051.435, Y: 547433.82, Elevation: 31.6
# Type: Text, X: 148974.558, Y: 548081.448, Elevation: 58.8
# Type: Text, X: 149152.792, Y: 547931.759, Elevation: 101.3
# Type: Text, X: 148623.129, Y: 547414.506, Elevation: 1.5
# Type: Text, X: 152951.71, Y: 549224.186, Elevation: 1.3
# Type: Text, X: 153022.115, Y: 548653.153, Elevation: 66.9
# Type: Text, X: 153459.861, Y: 548436.486, Elevation: 2.8
# Type: Text, X: 153481.93, Y: 548619.122, Elevation: 2.7
# Type: Text, X: 153284.749, Y: 548780.657, Elevation: 3.5
# Type: Text, X: 153215.079, Y: 549217.29, Elevation: 1.9
# Type: Text, X: 155355.858, Y: 554160.315, Elevation: 3.0
# Type: Text, X: 146557.138, Y: 555725.166, Elevation: 6.6
# Type: Text, X: 151455.456, Y: 555550.053, Elevation: 222.6
# Type: Text, X: 150883.398, Y: 555586.789, Elevation: 41.9
# Type: Text, X: 150397.791, Y: 555505.444, Elevation: 67.1
# Type: Text, X: 150505.882, Y: 554881.04, Elevation: 2.9
# Type: Text, X: 151583.338, Y: 555002.101, Elevation: 8.6
# Type: Text, X: 148689.424, Y: 546754.609, Elevation: 31.2
# Type: Text, X: 151472.096, Y: 546379.123, Elevation: 2.5
# Type: Text, X: 151081.818, Y: 546339.558, Elevation: 2.4
# Type: Text, X: 150769.294, Y: 546309.755, Elevation: 1.8
# Type: Text, X: 151497.735, Y: 546799.895, Elevation: 7.1
# Type: Text, X: 150989.775, Y: 546492.656, Elevation: 1.5
# Type: Text, X: 151107.028, Y: 547035.218, Elevation: 49.4
# Type: Text, X: 150730.929, Y: 546485.561, Elevation: 2.1
# Type: Text, X: 150575.423, Y: 546603.394, Elevation: 2.4
# Type: Text, X: 151289.165, Y: 546826.513, Elevation: 6.8
# Type: Text, X: 151205.997, Y: 546718.493, Elevation: 3.6
# Type: Text, X: 150820.173, Y: 546669.0, Elevation: 2.6
# Type: Text, X: 151079.641, Y: 546861.013, Elevation: 3.9
# Type: Text, X: 150441.792, Y: 546791.83, Elevation: 8.2
# Type: Text, X: 150436.676, Y: 546897.996, Elevation: 10.4
# Type: Text, X: 150867.285, Y: 546988.062, Elevation: 22.7
# Type: Text, X: 150841.39, Y: 546872.519, Elevation: 8.1
# Type: Text, X: 151474.921, Y: 546688.212, Elevation: 4.1
# Type: Text, X: 151263.33, Y: 546602.888, Elevation: 2.4
# Type: Text, X: 149366.412, Y: 547191.666, Elevation: 3.3
# Type: Text, X: 149359.126, Y: 547314.273, Elevation: 16.0
# Type: Text, X: 149303.124, Y: 547542.009, Elevation: 5.6
# Type: Text, X: 149265.129, Y: 547649.597, Elevation: 30.4
# Type: Text, X: 149574.674, Y: 547740.119, Elevation: 1.4
# Type: Text, X: 149474.9, Y: 547842.298, Elevation: 19.2
# Type: Text, X: 149473.47, Y: 547944.472, Elevation: 28.4
# Type: Text, X: 150274.967, Y: 547503.561, Elevation: 81.5
# Type: Text, X: 150187.356, Y: 547610.103, Elevation: 43.1
# Type: Text, X: 150348.844, Y: 547838.878, Elevation: 6.7
# Type: Text, X: 150167.004, Y: 547726.979, Elevation: 6.3
# Type: Text, X: 150002.617, Y: 547947.682, Elevation: 10.9
# Type: Text, X: 149875.184, Y: 547537.875, Elevation: 6.0
# Type: Text, X: 150081.457, Y: 547409.093, Elevation: 29.0
# Type: Text, X: 150195.588, Y: 547249.127, Elevation: 21.5
# Type: Text, X: 149331.097, Y: 548250.705, Elevation: 19.4
# Type: Text, X: 149777.993, Y: 547949.806, Elevation: 2.5
# Type: Text, X: 149847.125, Y: 548104.411, Elevation: 1.0
# Type: Text, X: 149664.71, Y: 548232.125, Elevation: 6.2
# Type: Text, X: 149492.259, Y: 548105.519, Elevation: 31.1
# Type: Text, X: 149858.97, Y: 547369.616, Elevation: 5.7
# Type: Text, X: 149876.376, Y: 547222.939, Elevation: 5.2
# Type: Text, X: 150244.743, Y: 548033.629, Elevation: 3.0
# Type: Text, X: 151664.537, Y: 547471.986, Elevation: 28.1
# Type: Text, X: 151277.866, Y: 547753.411, Elevation: 171.7
# Type: Text, X: 151593.543, Y: 547839.519, Elevation: 97.8
# Type: Text, X: 151312.557, Y: 547573.064, Elevation: 110.9
# Type: Text, X: 150808.451, Y: 547708.156, Elevation: 97.0
# Type: Text, X: 151602.996, Y: 548016.054, Elevation: 49.9
# Type: Text, X: 150449.896, Y: 548164.81, Elevation: 3.0
# Type: Text, X: 150464.69, Y: 547257.036, Elevation: 74.2
# Type: Text, X: 150477.981, Y: 547357.617, Elevation: 67.2
# Type: Text, X: 150777.536, Y: 547258.818, Elevation: 78.9
# Type: Text, X: 150525.041, Y: 547483.281, Elevation: 96.9
# Type: Text, X: 150779.665, Y: 548259.552, Elevation: 2.7
# Type: Text, X: 150871.391, Y: 547495.02, Elevation: 179.6
# Type: Text, X: 150638.766, Y: 547606.186, Elevation: 84.3
# Type: Text, X: 150469.935, Y: 547733.96, Elevation: 27.3
# Type: Text, X: 151574.012, Y: 548340.509, Elevation: 4.7
# Type: Text, X: 151215.468, Y: 547344.747, Elevation: 109.2
# Type: Text, X: 151068.845, Y: 547184.659, Elevation: 83.0
# Type: Text, X: 151636.138, Y: 547187.749, Elevation: 121.9
# Type: Text, X: 151371.055, Y: 547135.438, Elevation: 83.8
# Type: Text, X: 151586.373, Y: 548126.889, Elevation: 28.0
# Type: Text, X: 151273.752, Y: 548277.652, Elevation: 4.9
# Type: Text, X: 150873.603, Y: 548142.789, Elevation: 6.6
# Type: Text, X: 150955.871, Y: 547974.745, Elevation: 41.2
# Type: Text, X: 150453.634, Y: 547967.62, Elevation: 5.4
# Type: Text, X: 149224.891, Y: 549458.59, Elevation: 49.8
# Type: Text, X: 149823.341, Y: 548394.332, Elevation: 5.9
# Type: Text, X: 149870.188, Y: 548680.068, Elevation: 5.8
# Type: Text, X: 150423.197, Y: 547092.436, Elevation: 47.3
# Type: Text, X: 150410.325, Y: 546218.93, Elevation: -1.6
# Type: Text, X: 150245.656, Y: 546326.822, Elevation: 5.4
# Type: Text, X: 149237.725, Y: 546538.558, Elevation: 35.9
# Type: Text, X: 149223.327, Y: 546656.225, Elevation: 23.3
# Type: Text, X: 149566.833, Y: 546467.522, Elevation: 6.0
# Type: Text, X: 149714.024, Y: 547044.632, Elevation: 2.9
# Type: Text, X: 150107.239, Y: 547007.37, Elevation: 68.4
# Type: Text, X: 149712.117, Y: 546917.992, Elevation: 2.9
# Type: Text, X: 149602.199, Y: 546592.481, Elevation: 0.9
# Type: Text, X: 149574.008, Y: 546716.083, Elevation: 1.3
# Type: Text, X: 150356.588, Y: 546445.434, Elevation: 33.6
# Type: Text, X: 149808.953, Y: 546588.755, Elevation: 3.6
# Type: Text, X: 149833.018, Y: 546791.078, Elevation: 33.0
# Type: Text, X: 150344.883, Y: 546546.824, Elevation: 35.9
# Type: Text, X: 150021.701, Y: 546620.484, Elevation: 5.3
# Type: Text, X: 150184.094, Y: 546863.594, Elevation: 21.1
# Type: Text, X: 150080.811, Y: 546729.088, Elevation: 9.7
# Type: Text, X: 150319.834, Y: 546678.683, Elevation: 36.9
# Type: Text, X: 149182.533, Y: 546988.245, Elevation: 3.6
# Type: Text, X: 149755.226, Y: 546366.547, Elevation: 5.8
# Type: Text, X: 150007.487, Y: 546320.481, Elevation: 5.4
# Type: Text, X: 151873.997, Y: 546260.282, Elevation: 1.0
# Type: Text, X: 151758.722, Y: 546979.533, Elevation: 38.5
# Type: Text, X: 152900.762, Y: 547098.344, Elevation: 3.4
# Type: Text, X: 152760.265, Y: 545933.505, Elevation: 8.2
# Type: Text, X: 152846.568, Y: 546043.447, Elevation: 24.0
# Type: Text, X: 152905.282, Y: 546171.62, Elevation: 3.2
# Type: Text, X: 152469.967, Y: 546124.02, Elevation: 2.9
# Type: Text, X: 151787.613, Y: 546853.735, Elevation: 15.2
# Type: Text, X: 151680.055, Y: 546710.379, Elevation: 3.0
# Type: Text, X: 151700.779, Y: 546599.04, Elevation: 2.5
# Type: Text, X: 152299.525, Y: 547067.56, Elevation: 77.6
# Type: Text, X: 152646.511, Y: 547086.467, Elevation: 3.9
# Type: Text, X: 152559.969, Y: 546234.96, Elevation: 6.2
# Type: Text, X: 152816.613, Y: 546276.939, Elevation: 3.4
# Type: Text, X: 152243.919, Y: 546377.806, Elevation: 2.3
# Type: Text, X: 152922.369, Y: 546930.397, Elevation: 3.2
# Type: Text, X: 152889.895, Y: 546790.339, Elevation: 5.5
# Type: Text, X: 152109.507, Y: 546932.088, Elevation: 39.5
# Type: Text, X: 152504.935, Y: 546951.825, Elevation: 15.8
# Type: Text, X: 152556.277, Y: 546828.727, Elevation: 10.3
# Type: Text, X: 152173.805, Y: 546761.325, Elevation: 27.6
# Type: Text, X: 151925.873, Y: 546591.876, Elevation: 3.5
# Type: Text, X: 152128.754, Y: 546568.314, Elevation: 6.0
# Type: Text, X: 152421.202, Y: 546666.99, Elevation: 14.9
# Type: Text, X: 152891.167, Y: 546414.888, Elevation: 4.6
# Type: Text, X: 152564.169, Y: 546349.415, Elevation: 6.1
# Type: Text, X: 152308.908, Y: 546502.431, Elevation: 6.5
# Type: Text, X: 152796.504, Y: 546658.834, Elevation: 4.9
# Type: Text, X: 152841.122, Y: 546534.822, Elevation: 4.2
# Type: Text, X: 152599.833, Y: 546479.918, Elevation: 19.9
# Type: Text, X: 152119.674, Y: 546206.247, Elevation: 1.5
# Type: Text, X: 153157.485, Y: 546577.741, Elevation: 3.0
# Type: Text, X: 153190.173, Y: 546749.159, Elevation: 3.5
# Type: Text, X: 153124.19, Y: 546054.213, Elevation: 35.8
# Type: Text, X: 153812.298, Y: 546046.354, Elevation: 11.1
# Type: Text, X: 153221.588, Y: 546925.069, Elevation: 3.4
# Type: Text, X: 153132.211, Y: 547046.341, Elevation: 5.9
# Type: Text, X: 153281.401, Y: 546429.896, Elevation: 2.3
# Type: Text, X: 155365.424, Y: 546073.916, Elevation: 2.0
# Type: Text, X: 154844.578, Y: 546501.436, Elevation: 29.6
# Type: Text, X: 155372.169, Y: 546762.151, Elevation: 2.9
# Type: Text, X: 155373.422, Y: 546395.64, Elevation: 1.2
# Type: Text, X: 155353.413, Y: 546231.113, Elevation: 1.4
# Type: Text, X: 155418.807, Y: 546907.142, Elevation: 1.1
# Type: Text, X: 155456.886, Y: 545905.904, Elevation: 7.2
# Type: Text, X: 155731.422, Y: 546525.752, Elevation: 7.2
# Type: Text, X: 155805.394, Y: 546659.806, Elevation: 7.3
# Type: Text, X: 155737.804, Y: 546998.878, Elevation: 20.1
# Type: Text, X: 155623.286, Y: 546049.364, Elevation: 6.5
# Type: Text, X: 155442.648, Y: 547025.337, Elevation: 1.3
# Type: Text, X: 145345.054, Y: 547746.651, Elevation: 7.9
# Type: Text, X: 145375.427, Y: 547991.757, Elevation: 19.3
# Type: Text, X: 145335.358, Y: 547878.257, Elevation: 35.5
# Type: Text, X: 145045.327, Y: 548192.583, Elevation: 21.1
# Type: Text, X: 144794.398, Y: 547971.637, Elevation: 6.9
# Type: Text, X: 144933.091, Y: 548086.509, Elevation: 40.1
# Type: Text, X: 145013.94, Y: 547887.867, Elevation: 3.3
# Type: Text, X: 145492.158, Y: 548161.583, Elevation: 56.4
# Type: Text, X: 147204.508, Y: 548153.69, Elevation: 27.4
# Type: Text, X: 147388.081, Y: 547818.859, Elevation: 2.8
# Type: Text, X: 147475.669, Y: 548169.769, Elevation: 46.3
# Type: Text, X: 147346.069, Y: 547957.896, Elevation: 1.6
# Type: Text, X: 147745.047, Y: 548094.653, Elevation: 5.1
# Type: Text, X: 147675.06, Y: 547744.92, Elevation: 7.3
# Type: Text, X: 147702.552, Y: 547848.778, Elevation: 30.3
# Type: Text, X: 155579.446, Y: 547330.855, Elevation: 5.3
# Type: Text, X: 155677.976, Y: 547981.683, Elevation: 1.6
# Type: Text, X: 155528.144, Y: 547463.95, Elevation: 2.1
# Type: Text, X: 155644.746, Y: 547872.886, Elevation: 2.0
# Type: Text, X: 151978.676, Y: 547262.898, Elevation: 78.1
# Type: Text, X: 152048.665, Y: 547160.725, Elevation: 144.8
# Type: Text, X: 152446.72, Y: 548318.611, Elevation: 3.4
# Type: Text, X: 152707.502, Y: 547803.952, Elevation: 3.0
# Type: Text, X: 152764.101, Y: 547655.821, Elevation: 4.6
# Type: Text, X: 152330.202, Y: 547179.92, Elevation: 46.1
# Type: Text, X: 152224.743, Y: 547335.216, Elevation: 79.1
# Type: Text, X: 151892.204, Y: 548203.163, Elevation: 74.1
# Type: Text, X: 152112.743, Y: 548237.723, Elevation: 4.2
# Type: Text, X: 151994.053, Y: 548068.108, Elevation: 22.3
# Type: Text, X: 152290.211, Y: 548207.122, Elevation: 2.6
# Type: Text, X: 151891.954, Y: 547508.473, Elevation: 17.4
# Type: Text, X: 152544.88, Y: 548197.323, Elevation: 4.4
# Type: Text, X: 152434.694, Y: 548066.962, Elevation: 2.2
# Type: Text, X: 151922.035, Y: 547904.028, Elevation: 29.2
# Type: Text, X: 152692.495, Y: 548039.055, Elevation: 14.4
# Type: Text, X: 152521.441, Y: 547764.738, Elevation: 3.9
# Type: Text, X: 152729.976, Y: 547542.459, Elevation: 2.8
# Type: Text, X: 152246.049, Y: 547913.091, Elevation: 3.7
# Type: Text, X: 152293.789, Y: 547779.972, Elevation: 5.0
# Type: Text, X: 152327.157, Y: 547644.682, Elevation: 2.9
# Type: Text, X: 152026.086, Y: 547753.3, Elevation: 7.7
# Type: Text, X: 151871.999, Y: 547642.277, Elevation: 15.8
# Type: Text, X: 152117.514, Y: 547527.348, Elevation: 13.9
# Type: Text, X: 152457.862, Y: 547538.359, Elevation: 3.1
# Type: Text, X: 152495.303, Y: 547422.038, Elevation: 9.1
# Type: Text, X: 152560.472, Y: 547317.691, Elevation: 9.6
# Type: Text, X: 152640.948, Y: 547195.636, Elevation: 3.8
# Type: Text, X: 152769.875, Y: 547314.887, Elevation: 3.1
# Type: Text, X: 153076.09, Y: 547237.554, Elevation: 3.4
# Type: Text, X: 152997.39, Y: 547684.385, Elevation: 4.3
# Type: Text, X: 152927.509, Y: 548096.347, Elevation: 16.2
# Type: Text, X: 152960.7, Y: 547995.52, Elevation: 9.5
# Type: Text, X: 153463.284, Y: 548323.145, Elevation: 2.2
# Type: Text, X: 153494.511, Y: 548198.04, Elevation: 1.8
# Type: Text, X: 152991.835, Y: 547821.928, Elevation: 6.3
# Type: Text, X: 153159.857, Y: 548354.62, Elevation: 7.1
# Type: Text, X: 153004.692, Y: 548222.787, Elevation: 47.1
# Type: Text, X: 153277.359, Y: 548188.843, Elevation: 4.8
# Type: Text, X: 153447.586, Y: 548080.17, Elevation: 2.9
# Type: Text, X: 153237.702, Y: 548047.954, Elevation: 39.7
# Type: Text, X: 153472.668, Y: 547923.22, Elevation: 1.6
# Type: Text, X: 153229.024, Y: 547925.59, Elevation: 12.4
# Type: Text, X: 153252.683, Y: 547764.831, Elevation: 5.8
# Type: Text, X: 153275.93, Y: 547393.981, Elevation: 3.5
# Type: Text, X: 153353.784, Y: 547605.267, Elevation: 3.3
# Type: Text, X: 146672.495, Y: 548363.91, Elevation: 18.4
# Type: Text, X: 147893.051, Y: 548765.576, Elevation: 64.9
# Type: Text, X: 147801.408, Y: 548652.386, Elevation: 32.7
# Type: Text, X: 147525.048, Y: 548344.041, Elevation: 97.4
# Type: Text, X: 147808.858, Y: 548362.986, Elevation: 12.4
# Type: Text, X: 147568.637, Y: 548450.962, Elevation: 87.4
# Type: Text, X: 147512.413, Y: 548574.834, Elevation: 39.9
# Type: Text, X: 148171.724, Y: 549143.92, Elevation: 3.5
# Type: Text, X: 148973.666, Y: 549346.462, Elevation: 3.5
# Type: Text, X: 148944.203, Y: 549221.919, Elevation: 3.4
# Type: Text, X: 148929.941, Y: 548891.242, Elevation: 3.4
# Type: Text, X: 148799.534, Y: 548489.885, Elevation: 2.6
# Type: Text, X: 148103.178, Y: 548391.955, Elevation: 6.6
# Type: Text, X: 148203.895, Y: 548501.764, Elevation: 2.1
# Type: Text, X: 147972.111, Y: 548523.677, Elevation: 4.5
# Type: Text, X: 148125.482, Y: 548938.642, Elevation: 5.0
# Type: Text, X: 148178.833, Y: 548798.383, Elevation: 23.7
# Type: Text, X: 148218.276, Y: 548643.499, Elevation: 4.9
# Type: Text, X: 148490.339, Y: 548719.37, Elevation: 5.3
# Type: Text, X: 148846.599, Y: 548720.356, Elevation: 19.2
# Type: Text, X: 148785.9, Y: 548597.85, Elevation: 2.7
# Type: Text, X: 148841.09, Y: 549030.693, Elevation: 3.8
# Type: Text, X: 147523.37, Y: 555974.079, Elevation: 28.9
# Type: Text, X: 147496.401, Y: 556075.875, Elevation: 43.7
# Type: Text, X: 148795.473, Y: 555870.542, Elevation: 4.2
# Type: Text, X: 148915.066, Y: 556001.87, Elevation: 5.1
# Type: Text, X: 148562.425, Y: 555855.663, Elevation: 3.1
# Type: Text, X: 148177.943, Y: 555958.994, Elevation: 4.9
# Type: Text, X: 148904.7, Y: 556121.782, Elevation: 5.8
# Type: Text, X: 148698.001, Y: 556084.63, Elevation: 5.9
# Type: Text, X: 148428.505, Y: 556043.873, Elevation: 5.3
# Type: Text, X: 148681.137, Y: 556205.063, Elevation: 6.4
# Type: Text, X: 148811.476, Y: 556324.107, Elevation: 7.6
# Type: Text, X: 148482.85, Y: 556279.913, Elevation: 6.1
# Type: Text, X: 149106.046, Y: 556372.687, Elevation: 16.4
# Type: Text, X: 149109.979, Y: 556482.309, Elevation: 22.6
# Type: Text, X: 148247.931, Y: 556150.215, Elevation: 5.8
# Type: Text, X: 147953.048, Y: 556332.623, Elevation: 39.4
# Type: Text, X: 148239.017, Y: 556300.431, Elevation: 6.7
# Type: Text, X: 148020.206, Y: 556456.909, Elevation: 33.5
# Type: Text, X: 148821.256, Y: 556464.694, Elevation: 11.1
# Type: Text, X: 148172.673, Y: 556578.677, Elevation: 22.9
# Type: Text, X: 148445.087, Y: 556412.041, Elevation: 9.5
# Type: Text, X: 148754.46, Y: 557001.275, Elevation: 41.0
# Type: Text, X: 148150.636, Y: 557026.041, Elevation: 39.2
# Type: Text, X: 148201.653, Y: 556917.826, Elevation: 33.5
# Type: Text, X: 148440.828, Y: 556519.788, Elevation: 9.1
# Type: Text, X: 148160.587, Y: 556717.309, Elevation: 27.6
# Type: Text, X: 148813.206, Y: 556594.712, Elevation: 14.3
# Type: Text, X: 148788.583, Y: 556721.54, Elevation: 15.6
# Type: Text, X: 148443.716, Y: 556717.541, Elevation: 12.9
# Type: Text, X: 148529.14, Y: 556894.17, Elevation: 22.7
# Type: Text, X: 150550.911, Y: 558399.925, Elevation: 112.7
# Type: Text, X: 150881.171, Y: 556817.884, Elevation: 278.0
# Type: Text, X: 151157.624, Y: 556748.595, Elevation: 227.2
# Type: Text, X: 151044.881, Y: 556596.893, Elevation: 183.3
# Type: Text, X: 150969.592, Y: 556293.158, Elevation: 242.1
# Type: Text, X: 151217.658, Y: 556155.963, Elevation: 251.6
# Type: Text, X: 151382.377, Y: 557042.097, Elevation: 73.3
# Type: Text, X: 151432.085, Y: 555884.378, Elevation: 258.3
# Type: Text, X: 151354.874, Y: 555996.396, Elevation: 256.1
# Type: Text, X: 151367.285, Y: 556388.412, Elevation: 122.9
# Type: Text, X: 150605.755, Y: 556547.508, Elevation: 267.4
# Type: Text, X: 151687.884, Y: 556233.798, Elevation: 62.1
# Type: Text, X: 152849.643, Y: 555932.04, Elevation: 2.8
# Type: Text, X: 152787.671, Y: 556041.131, Elevation: 2.9
# Type: Text, X: 152600.363, Y: 555948.836, Elevation: 2.9
# Type: Text, X: 152749.316, Y: 556148.249, Elevation: 3.2
# Type: Text, X: 152846.662, Y: 556330.502, Elevation: 2.8
# Type: Text, X: 152463.166, Y: 556074.188, Elevation: 2.6
# Type: Text, X: 152724.486, Y: 556467.449, Elevation: 4.4
# Type: Text, X: 152478.528, Y: 556295.145, Elevation: 3.4
# Type: Text, X: 152431.189, Y: 556430.745, Elevation: 3.6
# Type: Text, X: 152782.687, Y: 556648.106, Elevation: 3.7
# Type: Text, X: 152291.578, Y: 556186.235, Elevation: 2.7
# Type: Text, X: 152624.759, Y: 557101.735, Elevation: 4.1
# Type: Text, X: 152819.473, Y: 556857.618, Elevation: 3.8
# Type: Text, X: 152736.572, Y: 556957.556, Elevation: 4.2
# Type: Text, X: 152515.975, Y: 556662.469, Elevation: 4.8
# Type: Text, X: 152209.781, Y: 555882.462, Elevation: 9.6
# Type: Text, X: 152011.992, Y: 555983.125, Elevation: 22.9
# Type: Text, X: 152077.446, Y: 556157.303, Elevation: 8.1
# Type: Text, X: 152166.014, Y: 556301.509, Elevation: 2.4
# Type: Text, X: 151929.629, Y: 556444.86, Elevation: 56.9
# Type: Text, X: 151626.182, Y: 556954.261, Elevation: 41.4
# Type: Text, X: 152272.375, Y: 556605.688, Elevation: 4.9
# Type: Text, X: 152034.272, Y: 556683.554, Elevation: 12.2
# Type: Text, X: 152380.175, Y: 557079.657, Elevation: 3.8
# Type: Text, X: 152315.522, Y: 556749.796, Elevation: 4.2
# Type: Text, X: 152436.975, Y: 556900.995, Elevation: 3.5
# Type: Text, X: 152162.388, Y: 557090.612, Elevation: 5.9
# Type: Text, X: 152133.079, Y: 556854.555, Elevation: 4.8
# Type: Text, X: 152195.786, Y: 556962.201, Elevation: 4.9
# Type: Text, X: 151875.27, Y: 556951.828, Elevation: 22.2
# Type: Text, X: 153094.09, Y: 556685.917, Elevation: 3.7
# Type: Text, X: 153025.898, Y: 556930.104, Elevation: 3.8
# Type: Text, X: 152975.916, Y: 556202.311, Elevation: 1.8
# Type: Text, X: 153120.581, Y: 556322.966, Elevation: 2.2
# Type: Text, X: 153055.416, Y: 555963.623, Elevation: 3.1
# Type: Text, X: 153299.964, Y: 556048.616, Elevation: 2.5
# Type: Text, X: 153346.688, Y: 557042.569, Elevation: 3.8
# Type: Text, X: 153352.495, Y: 556507.854, Elevation: 3.8
# Type: Text, X: 153908.304, Y: 555869.535, Elevation: 6.3
# Type: Text, X: 153323.738, Y: 556873.328, Elevation: 3.4
# Type: Text, X: 153303.642, Y: 556221.235, Elevation: 3.7
# Type: Text, X: 153523.834, Y: 556015.151, Elevation: 4.5
# Type: Text, X: 153554.096, Y: 556378.727, Elevation: 2.4
# Type: Text, X: 153545.853, Y: 556237.192, Elevation: 2.3
# Type: Text, X: 153875.263, Y: 555989.521, Elevation: 6.7
# Type: Text, X: 153439.094, Y: 556712.057, Elevation: 2.5
# Type: Text, X: 153653.147, Y: 556670.919, Elevation: 1.8
# Type: Text, X: 153595.085, Y: 556543.732, Elevation: 0.6
# Type: Text, X: 155769.707, Y: 557801.621, Elevation: 31.1
# Type: Text, X: 155684.771, Y: 557947.472, Elevation: 32.4
# Type: Text, X: 145328.274, Y: 558333.713, Elevation: 28.9
# Type: Text, X: 144883.7, Y: 558383.132, Elevation: 5.7
# Type: Text, X: 145211.715, Y: 558433.456, Elevation: 20.4
# Type: Text, X: 145147.739, Y: 558553.671, Elevation: 17.7
# Type: Text, X: 144869.242, Y: 558554.181, Elevation: 6.2
# Type: Text, X: 147765.398, Y: 558372.518, Elevation: 94.3
# Type: Text, X: 149023.437, Y: 558344.982, Elevation: 177.7
# Type: Text, X: 149819.901, Y: 558393.443, Elevation: 173.3
# Type: Text, X: 149396.265, Y: 558498.871, Elevation: 137.4
# Type: Text, X: 149391.129, Y: 558376.773, Elevation: 148.1
# Type: Text, X: 153365.564, Y: 558363.552, Elevation: 3.5
# Type: Text, X: 153647.643, Y: 558451.984, Elevation: 4.2
# Type: Text, X: 154076.57, Y: 558449.083, Elevation: 16.5
# Type: Text, X: 151046.505, Y: 558445.076, Elevation: 36.3
# Type: Text, X: 152754.674, Y: 558432.577, Elevation: 5.3
# Type: Text, X: 152467.068, Y: 558370.152, Elevation: 30.7
# Type: Text, X: 152473.035, Y: 558494.775, Elevation: 12.8
# Type: Text, X: 152066.22, Y: 558373.183, Elevation: 15.2
# Type: Text, X: 154401.285, Y: 558437.447, Elevation: 18.9
# Type: Text, X: 154735.393, Y: 558405.949, Elevation: 57.7
# Type: Text, X: 155267.492, Y: 558410.617, Elevation: 20.6
# Type: Text, X: 155858.997, Y: 558479.799, Elevation: 14.3
# Type: Text, X: 150993.412, Y: 547393.023, Elevation: 178.8
# Type: Text, X: 146861.843, Y: 555437.759, Elevation: 6.7
# Type: Text, X: 152343.148, Y: 555161.185, Elevation: 83.2
# Type: Text, X: 155014.001, Y: 556879.032, Elevation: 335.1
# Type: Text, X: 145450.569, Y: 557808.153, Elevation: 14.9
# Type: Text, X: 146346.651, Y: 556812.593, Elevation: 13.2
# Type: Text, X: 148243.027, Y: 556476.798, Elevation: 13.7
# Type: Text, X: 151854.943, Y: 555032.234, Elevation: 9.5
# Type: Text, X: 152423.491, Y: 555751.871, Elevation: 22.1
# Type: Text, X: 152058.597, Y: 557554.543, Elevation: 7.6
# Type: Text, X: 149750.72, Y: 548054.855, Elevation: 6.2
# Type: Text, X: 153906.566, Y: 556212.182, Elevation: 3.8
# Type: Text, X: 153699.783, Y: 557655.854, Elevation: 13.3
# Type: Text, X: 149221.863, Y: 556107.915, Elevation: 8.9
# Type: Text, X: 146997.541, Y: 556007.148, Elevation: 26.4
# Type: Text, X: 145541.685, Y: 557505.289, Elevation: 11.3
# Type: Text, X: 152414.293, Y: 554715.753, Elevation: 9.3

# %%
import ezdxf
import pandas as pd
from scipy.spatial import cKDTree
import numpy as np

def extract_elevation_from_dxf(file_path):
    try:
        # DXF 파일 로드
        doc = ezdxf.readfile(file_path)
        msp = doc.modelspace()

        # 결과를 저장할 리스트
        polyline_data = []
        text_data = []

        # 1. 3D 폴리라인에서 Z-좌표(고도) 및 시작/끝 좌표 추출
        for entity in msp.query('POLYLINE LWPOLYLINE'):
            if entity.dxftype() == 'POLYLINE' and entity.is_3d_polyline:
                # 3D Polyline
                vertices = list(entity.vertices())
                start_vertex = vertices[0].dxf.location
                end_vertex = vertices[-1].dxf.location
                polyline_data.append({
                    'type': '3D Polyline',
                    'start_x': start_vertex[0],
                    'start_y': start_vertex[1],
                    'start_z': start_vertex[2],
                    'end_x': end_vertex[0],
                    'end_y': end_vertex[1],
                    'end_z': end_vertex[2]
                })
            elif entity.dxftype() == 'LWPOLYLINE':
                # 2D Polyline
                points = entity.get_points()
                start_point = points[0]
                end_point = points[-1]
                polyline_data.append({
                    'type': '2D Polyline',
                    'start_x': start_point[0],
                    'start_y': start_point[1],
                    'start_z': 0,
                    'end_x': end_point[0],
                    'end_y': end_point[1],
                    'end_z': 0
                })

        # 2. 텍스트 엔티티에서 고도 데이터 추출
        for entity in msp.query('TEXT MTEXT'):
            text = entity.dxf.text
            try:
                elevation = float(text)
                text_data.append({
                    'x': entity.dxf.insert[0],
                    'y': entity.dxf.insert[1],
                    'elevation': elevation
                })
            except ValueError:
                continue

        # 데이터프레임 생성
        polyline_df = pd.DataFrame(polyline_data)
        text_df = pd.DataFrame(text_data)

        # KDTree를 사용하여 가장 가까운 텍스트 고도 매칭
        tree = cKDTree(text_df[['x', 'y']].values)
        for i, row in polyline_df.iterrows():
            # 시작점 고도 매칭
            start_dist, start_idx = tree.query([row['start_x'], row['start_y']])
            end_dist, end_idx = tree.query([row['end_x'], row['end_y']])
            start_elevation = text_df.iloc[start_idx]['elevation']
            end_elevation = text_df.iloc[end_idx]['elevation']

            # 기울기 계산
            distance = np.sqrt((row['end_x'] - row['start_x']) ** 2 + (row['end_y'] - row['start_y']) ** 2)
            slope = (end_elevation - start_elevation) / distance if distance != 0 else 0

            polyline_df.at[i, 'start_elevation'] = start_elevation
            polyline_df.at[i, 'end_elevation'] = end_elevation
            polyline_df.at[i, 'slope'] = slope

        return polyline_df

    except Exception as e:
        print(f"Error reading DXF file: {e}")
        return pd.DataFrame()

# 사용 예시
file_path = 'C:/Users/user/Desktop/인천시공공데이터공모전/376064.dxf'  # DXF 파일 경로
roads = extract_elevation_from_dxf(file_path)
print(roads)
# Out:
#               type     start_x     start_y  start_z       end_x       end_y  \
# 0      2D Polyline  155846.160  555720.470        0  155846.160  555720.470
# 1      2D Polyline  155729.982  544621.871        0  155787.604  544710.746
# 2      2D Polyline  155787.604  544710.746        0  155787.604  544710.746
# 3      2D Polyline  155775.077  544621.626        0  155775.077  544621.626
# 4      2D Polyline  155787.229  544640.138        0  155775.077  544621.626
# ...            ...         ...         ...      ...         ...         ...
# 24953  2D Polyline  147735.684  555306.790        0  147735.684  555306.790
# 24954  2D Polyline  149833.320  558390.619        0  149833.320  558390.619
# 24955  2D Polyline  149790.800  557420.266        0  149790.800  557420.266
# 24956  2D Polyline  149658.624  557493.593        0  149658.624  557493.593
# 24957  2D Polyline  154859.327  555835.386        0  154859.327  555835.386
#
#        end_z  start_elevation  end_elevation  slope
# 0          0             15.2           15.2    0.0
# 1          0             12.4           12.4    0.0
# 2          0             12.4           12.4    0.0
# 3          0             12.4           12.4    0.0
# 4          0             12.4           12.4    0.0
# ...      ...              ...            ...    ...
# 24953      0             52.3           52.3    0.0
# 24954      0            173.3          173.3    0.0
# 24955      0            400.0          400.0    0.0
# 24956      0            472.1          472.1    0.0
# 24957      0              6.2            6.2    0.0
#
# [24958 rows x 10 columns]

# %%
import geopandas as gpd
import pandas as pd

# SHP 파일 경로 (인천시 도로망 SHP 파일 예시)
shp_path = "C:/Users/user/Desktop/인천시공공데이터공모전/인천광역시_도로시설데이터_선/인천광역시_도로시설데이터_선.shp"

# SHP 파일을 GeoDataFrame으로 읽기
gdf = gpd.read_file(shp_path)

# GeoDataFrame의 첫 몇 행 확인
print("GeoDataFrame 미리보기:")
print(gdf.head())

# GeoDataFrame의 컬럼 확인
print("\n컬럼 목록:")
print(gdf.columns)

# 지오메트리 열을 포함한 GeoDataFrame을 그대로 사용하거나
# 지오메트리 열을 제외하고 Pandas DataFrame으로 변환
df = pd.DataFrame(gdf.drop(columns=['geometry']))

# Pandas DataFrame 확인
print("\nPandas DataFrame 미리보기:")
print(df.head())

# 필요하면 CSV로 저장
df.to_csv("C:/Users/user/Desktop/인천시공공데이터공모전/incheon_roads.csv", index=False, encoding='utf-8')
# Out:
# GeoDataFrame 미리보기:
#    number   etc emd_nm                regist_dt    emd_cd sgg_cd sido_nm  \
# 0   73550  null    신포동  2021-11-30T02:28:47.348  28110124  28110   인천광역시
# 1   73551  null    신포동  2021-11-30T02:28:47.348  28110124  28110   인천광역시
# 2   73552  null    신포동  2021-11-30T02:28:47.348  28110124  28110   인천광역시
# 3   73571  null    신포동  2021-11-30T02:28:47.348  28110124  28110   인천광역시
# 4   73603  null    신포동  2021-11-30T02:28:47.348  28110124  28110   인천광역시
#
#   sido_cd sgg_nm master_cd master_nm detail_nm  \
# 0      28     중구       901       도로선    외곽선-실선
# 1      28     중구       901       도로선    외곽선-실선
# 2      28     중구       901       도로선    외곽선-실선
# 3      28     중구       901       도로선    외곽선-실선
# 4      28     중구       901       도로선     차선-점선
#
#                                             geometry
# 0  LINESTRING (922712.14 1941763.881, 922713.898 ...
# 1  LINESTRING (922718.187 1941762.23, 922719.839 ...
# 2  LINESTRING (922755.737 1941753.605, 922757.749...
# 3  LINESTRING (922662.732 1941745.422, 922665.468...
# 4  LINESTRING (922894.817 1941660.36, 922886.652 ...
#
# 컬럼 목록:
# Index(['number', 'etc', 'emd_nm', 'regist_dt', 'emd_cd', 'sgg_cd', 'sido_nm',
#        'sido_cd', 'sgg_nm', 'master_cd', 'master_nm', 'detail_nm', 'geometry'],
#       dtype='object')
#
# Pandas DataFrame 미리보기:
#    number   etc emd_nm                regist_dt    emd_cd sgg_cd sido_nm  \
# 0   73550  null    신포동  2021-11-30T02:28:47.348  28110124  28110   인천광역시
# 1   73551  null    신포동  2021-11-30T02:28:47.348  28110124  28110   인천광역시
# 2   73552  null    신포동  2021-11-30T02:28:47.348  28110124  28110   인천광역시
# 3   73571  null    신포동  2021-11-30T02:28:47.348  28110124  28110   인천광역시
# 4   73603  null    신포동  2021-11-30T02:28:47.348  28110124  28110   인천광역시
#
#   sido_cd sgg_nm master_cd master_nm detail_nm
# 0      28     중구       901       도로선    외곽선-실선
# 1      28     중구       901       도로선    외곽선-실선
# 2      28     중구       901       도로선    외곽선-실선
# 3      28     중구       901       도로선    외곽선-실선
# 4      28     중구       901       도로선     차선-점선
